# %% [markdown]
# # LeNet-5
#
# Idea from: LeNet-5 - GradientBased Learning Applied to Document Recognition (Yann LeCun Leon Bottou Yoshua Bengio and Patrick Haffner) (http://vision.stanford.edu/cs598_spring07/papers/Lecun98.pdf)
#
# ### Structure of model
#
# 1. Convolutional layer
#
# 2. RelU
#
# 3. MaxPool
#
# 4. Convolutional layer
#
# 5. RelU
#
# 6. MaxPool
#
# 7. Convolutional layer
#
# 8. Fully connected layers
#
# 5. RelU
#
# 8. Fully connected layers
#
# 9. Output
#
# ### Time took to train model
#
# 26m 14s for 100 epochs

# %%
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torchvision import datasets
from torch.utils.data import DataLoader
import torch.optim as optim
import torchvision
import numpy as np
from torchvision import transforms
import random
import os

# %%
class LeNet_5(nn.Module):
    def __init__(self):
        super(LeNet_5,self).__init__()
        self.c1 = nn.Conv2d(1,6,5)
        self.maxpool1 = nn.MaxPool2d(2)
        self.c2 = nn.Conv2d(6,16,5)
        self.maxpool2 = nn.MaxPool2d(2)
        self.c3 = nn.Conv2d(16,120,5)
        self.n1 = nn.Linear(120,84)
        self.relu = nn.ReLU()
        self.n2 = nn.Linear(84,10)

    def forward(self,x):
        x = self.c1(x)
        x = self.relu(x)
        x = self.maxpool1(x)
        x = self.c2(x)
        x = self.relu(x)
        x = self.maxpool2(x)
        x = self.c3(x)
        x = self.relu(x)
        x = torch.flatten(x,1)
        x = self.n1(x)
        x = self.relu(x)
        x = self.n2(x)
        return x

# %%
USE_CUDA = torch.cuda.is_available()
device = torch.device("cuda" if USE_CUDA else "cpu")

# %%
DOWNLOAD_ROOT = os.path.join(os.pardir,"MNIST_data")

dataset_1 = datasets.MNIST(root=DOWNLOAD_ROOT,train=True,transform=transforms.Compose([transforms.Resize((32,32)),transforms.ToTensor()]),download=True)
dataset_2 = datasets.MNIST(root=DOWNLOAD_ROOT,train=False,transform=transforms.Compose([transforms.Resize((32,32)),transforms.ToTensor()]),download=True)

# %%
BATCH_SIZE = 128
dataset_1_loader = DataLoader(dataset_1, batch_size=BATCH_SIZE, shuffle=True,drop_last=True)
dataset_2_loader = DataLoader(dataset_2, batch_size=BATCH_SIZE, shuffle=True,drop_last=True)

# %%
LOAD = False
LEARNING_RATE = 0.01
SEED = 7777
torch.manual_seed(SEED)
if device == 'cuda':
    torch.cuda.manual_seed_all(SEED)
model = LeNet_5()
model.zero_grad()
loss_function = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(),lr=LEARNING_RATE)
TOTAL_BATCH = len(dataset_1_loader)
EPOCHS = 100
loss_list = []
accuracy_list = []
epoch = 0

# %%
PATH = os.path.join("Saves","pretrained_model.pt")
SAVE_INTERVAL = 5
if LOAD:
    check = torch.load(PATH)
    model.load_state_dict(check["model"])
    epoch = check["epoch"]
    accuracy_list = check["accuracy list"]
    loss_list = check["loss list"]
    optimizer.load_state_dict(check["optimizer"])

# %%
while epoch < EPOCHS:
    cost = 0
    for image, label in dataset_1_loader:
        optimizer.zero_grad()
        predicted = model.forward(image)
        loss = loss_function(predicted,label)
        loss.backward()
        optimizer.step()
        cost+=loss
    with torch.no_grad():
        total = 0
        correct = 0
        for image, label in dataset_2_loader:
            out = model(image)
            _,predict = torch.max(out.data, 1)
            total += label.size(0)
            correct += (predict==label).sum()
    average_cost = cost/TOTAL_BATCH
    accuracy = 100*correct/total
    loss_list.append(average_cost.detach().numpy())
    accuracy_list.append(accuracy)
    epoch+=1
    print("epoch : {} | loss : {:.6f}" .format(epoch, average_cost))
    print("Accuracy : {:.2f}".format(accuracy))
    print("---------------------")
    if epoch%5 ==0:
        torch.save({"epoch":epoch,"loss list":loss_list,"accuracy list":accuracy_list,"model":model.state_dict(),"optimizer":optimizer.state_dict()},PATH)
# Out:
# epoch : 1 | loss : 2.300285
# Accuracy : 11.35
# ---------------------
# epoch : 2 | loss : 2.285102
# Accuracy : 28.29
# ---------------------
# epoch : 3 | loss : 1.529320
# Accuracy : 81.72
# ---------------------
# epoch : 4 | loss : 0.481597
# Accuracy : 89.04
# ---------------------
# epoch : 5 | loss : 0.339278
# Accuracy : 91.64
# ---------------------
# epoch : 6 | loss : 0.271110
# Accuracy : 92.82
# ---------------------
# epoch : 7 | loss : 0.225575
# Accuracy : 94.24
# ---------------------
# epoch : 8 | loss : 0.193359
# Accuracy : 95.09
# ---------------------
# epoch : 9 | loss : 0.166223
# Accuracy : 95.39
# ---------------------
# epoch : 10 | loss : 0.148601
# Accuracy : 96.26
# ---------------------
# epoch : 11 | loss : 0.131567
# Accuracy : 96.49
# ---------------------
# epoch : 12 | loss : 0.119991
# Accuracy : 96.58
# ---------------------
# epoch : 13 | loss : 0.110049
# Accuracy : 96.80
# ---------------------
# epoch : 14 | loss : 0.101961
# Accuracy : 96.96
# ---------------------
# epoch : 15 | loss : 0.094535
# Accuracy : 97.41
# ---------------------
# epoch : 16 | loss : 0.088559
# Accuracy : 97.51
# ---------------------
# epoch : 17 | loss : 0.084398
# Accuracy : 97.57
# ---------------------
# epoch : 18 | loss : 0.079715
# Accuracy : 97.76
# ---------------------
# epoch : 19 | loss : 0.074289
# Accuracy : 97.68
# ---------------------
# epoch : 20 | loss : 0.071105
# Accuracy : 97.82
# ---------------------
# epoch : 21 | loss : 0.067925
# Accuracy : 97.85
# ---------------------
# epoch : 22 | loss : 0.064921
# Accuracy : 98.00
# ---------------------
# epoch : 23 | loss : 0.062762
# Accuracy : 98.05
# ---------------------
# epoch : 24 | loss : 0.059833
# Accuracy : 97.99
# ---------------------
# epoch : 25 | loss : 0.057008
# Accuracy : 98.23
# ---------------------
# epoch : 26 | loss : 0.055384
# Accuracy : 98.03
# ---------------------
# epoch : 27 | loss : 0.052815
# Accuracy : 98.04
# ---------------------
# epoch : 28 | loss : 0.051408
# Accuracy : 98.27
# ---------------------
# epoch : 29 | loss : 0.049448
# Accuracy : 98.45
# ---------------------
# epoch : 30 | loss : 0.047594
# Accuracy : 98.36
# ---------------------
# epoch : 31 | loss : 0.046446
# Accuracy : 98.19
# ---------------------
# epoch : 32 | loss : 0.044894
# Accuracy : 98.28
# ---------------------
# epoch : 33 | loss : 0.044082
# Accuracy : 98.32
# ---------------------
# epoch : 34 | loss : 0.042462
# Accuracy : 98.23
# ---------------------
# epoch : 35 | loss : 0.041212
# Accuracy : 98.51
# ---------------------
# epoch : 36 | loss : 0.039510
# Accuracy : 98.56
# ---------------------
# epoch : 37 | loss : 0.039444
# Accuracy : 98.49
# ---------------------
# epoch : 38 | loss : 0.037406
# Accuracy : 98.63
# ---------------------
# epoch : 39 | loss : 0.036793
# Accuracy : 98.57
# ---------------------
# epoch : 40 | loss : 0.035874
# Accuracy : 98.59
# ---------------------
# epoch : 41 | loss : 0.035085
# Accuracy : 98.68
# ---------------------
# epoch : 42 | loss : 0.033953
# Accuracy : 98.58
# ---------------------
# epoch : 43 | loss : 0.033248
# Accuracy : 98.62
# ---------------------
# epoch : 44 | loss : 0.032089
# Accuracy : 98.56
# ---------------------
# epoch : 45 | loss : 0.031039
# Accuracy : 98.68
# ---------------------
# epoch : 46 | loss : 0.030912
# Accuracy : 98.72
# ---------------------
# epoch : 47 | loss : 0.029339
# Accuracy : 98.65
# ---------------------
# epoch : 48 | loss : 0.029294
# Accuracy : 98.82
# ---------------------
# epoch : 49 | loss : 0.028698
# Accuracy : 98.62
# ---------------------
# epoch : 50 | loss : 0.027698
# Accuracy : 98.58
# ---------------------
# epoch : 51 | loss : 0.027206
# Accuracy : 98.74
# ---------------------
# epoch : 52 | loss : 0.026202
# Accuracy : 98.77
# ---------------------
# epoch : 53 | loss : 0.025361
# Accuracy : 98.70
# ---------------------
# epoch : 54 | loss : 0.025552
# Accuracy : 98.62
# ---------------------
# epoch : 55 | loss : 0.024854
# Accuracy : 98.75
# ---------------------
# epoch : 56 | loss : 0.024227
# Accuracy : 98.48
# ---------------------
# epoch : 57 | loss : 0.024023
# Accuracy : 98.65
# ---------------------
# epoch : 58 | loss : 0.022948
# Accuracy : 98.88
# ---------------------
# epoch : 59 | loss : 0.022050
# Accuracy : 98.58
# ---------------------
# epoch : 60 | loss : 0.021855
# Accuracy : 98.79
# ---------------------
# epoch : 61 | loss : 0.021432
# Accuracy : 98.64
# ---------------------
# epoch : 62 | loss : 0.020652
# Accuracy : 98.72
# ---------------------
# epoch : 63 | loss : 0.020445
# Accuracy : 98.80
# ---------------------
# epoch : 64 | loss : 0.019551
# Accuracy : 98.68
# ---------------------
# epoch : 65 | loss : 0.019655
# Accuracy : 98.76
# ---------------------
# epoch : 66 | loss : 0.018792
# Accuracy : 98.81
# ---------------------
# epoch : 67 | loss : 0.018529
# Accuracy : 98.83
# ---------------------
# epoch : 68 | loss : 0.018281
# Accuracy : 98.71
# ---------------------
# epoch : 69 | loss : 0.017443
# Accuracy : 98.79
# ---------------------
# epoch : 70 | loss : 0.017347
# Accuracy : 98.80
# ---------------------
# epoch : 71 | loss : 0.016914
# Accuracy : 98.89
# ---------------------
# epoch : 72 | loss : 0.017326
# Accuracy : 98.77
# ---------------------
# epoch : 73 | loss : 0.016324
# Accuracy : 98.89
# ---------------------
# epoch : 74 | loss : 0.015452
# Accuracy : 98.80
# ---------------------
# epoch : 75 | loss : 0.015342
# Accuracy : 98.82
# ---------------------
# epoch : 76 | loss : 0.015225
# Accuracy : 98.80
# ---------------------
# epoch : 77 | loss : 0.014776
# Accuracy : 98.85
# ---------------------
# epoch : 78 | loss : 0.014226
# Accuracy : 98.81
# ---------------------
# epoch : 79 | loss : 0.014119
# Accuracy : 98.77
# ---------------------
# epoch : 80 | loss : 0.013747
# Accuracy : 98.82
# ---------------------
# epoch : 81 | loss : 0.013419
# Accuracy : 98.75
# ---------------------
# epoch : 82 | loss : 0.013156
# Accuracy : 98.76
# ---------------------
# epoch : 83 | loss : 0.013089
# Accuracy : 98.85
# ---------------------
# epoch : 84 | loss : 0.011970
# Accuracy : 98.86
# ---------------------
# epoch : 85 | loss : 0.011913
# Accuracy : 98.89
# ---------------------
# epoch : 86 | loss : 0.011732
# Accuracy : 98.70
# ---------------------
# epoch : 87 | loss : 0.011362
# Accuracy : 98.74
# ---------------------
# epoch : 88 | loss : 0.011254
# Accuracy : 98.78
# ---------------------
# epoch : 89 | loss : 0.011048
# Accuracy : 98.93
# ---------------------
# epoch : 90 | loss : 0.010304
# Accuracy : 98.88
# ---------------------
# epoch : 91 | loss : 0.010618
# Accuracy : 98.83
# ---------------------
# epoch : 92 | loss : 0.010946
# Accuracy : 98.91
# ---------------------
# epoch : 93 | loss : 0.009904
# Accuracy : 98.88
# ---------------------
# epoch : 94 | loss : 0.009935
# Accuracy : 98.81
# ---------------------
# epoch : 95 | loss : 0.009248
# Accuracy : 98.81
# ---------------------
# epoch : 96 | loss : 0.009715
# Accuracy : 98.80
# ---------------------
# epoch : 97 | loss : 0.008635
# Accuracy : 98.82
# ---------------------
# epoch : 98 | loss : 0.008921
# Accuracy : 98.81
# ---------------------
# epoch : 99 | loss : 0.008707
# Accuracy : 98.90
# ---------------------
# epoch : 100 | loss : 0.008893
# Accuracy : 98.82
# ---------------------

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.text(EPOCHS-1-15,loss_list[-1]+0.1,'({:.3f})'.format(loss_list[-1]))
plt.plot(np.arange(0,EPOCHS),loss_list)
plt.subplot(1,2,2)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.text(EPOCHS-1-15,accuracy_list[-1]-3,'({:.1f}%)'.format(accuracy_list[-1]))
plt.plot(np.arange(0,EPOCHS), accuracy_list)
plt.savefig('graph.png',facecolor = 'w')
plt.show()

# %%
figure = plt.figure(figsize=(8, 8))
cols, rows = 3, 3
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(dataset_2), size=(1,)).item()
    img, label = dataset_2[sample_idx]
    figure.add_subplot(rows, cols, i)
    img = torch.unsqueeze(img,0)
    out = model(img)
    _,predict = torch.max(out.data, 1)
    plt.title("label: {} actual: {}".format(label,predict.item()))
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
    plt.savefig('output.png',facecolor = 'w')
plt.show()
