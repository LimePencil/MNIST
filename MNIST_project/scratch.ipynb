# %%
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torchvision import datasets
from torch.utils.data import DataLoader
import torch.optim as optim
import torchvision
import numpy as np
from torchvision import transforms
import random
import os

# %%
class n_net(nn.Module):
    def __init__(self):
        super(n_net,self).__init__()
        self.n1 = nn.Linear(784,100)
        self.relu = nn.ReLU()
        self.n2 = nn.Linear(100,100)
        self.n3 = nn.Linear(100,10)
    def forward(self,x):
        x1 = self.n1(x)
        x2 = self.relu(x1)
        x3 = self.n2(x2)
        x4 = self.relu(x3)
        x5 = self.n3(x4)
        return x5

# %%
USE_CUDA = torch.cuda.is_available()
device = torch.device("cuda" if USE_CUDA else "cpu")

# %%
DOWNLOAD_ROOT = 'MNIST_data/'

dataset_1 = datasets.MNIST(root=DOWNLOAD_ROOT,train=True,transform=transforms.ToTensor(),download=True)
dataset_2 = datasets.MNIST(root=DOWNLOAD_ROOT,train=False,transform=transforms.ToTensor(),download=True)

# %%
BATCH_SIZE = 128
dataset_1_loader = DataLoader(dataset_1, batch_size=BATCH_SIZE, shuffle=True,drop_last=True)
dataset_2_loader = DataLoader(dataset_2, batch_size=BATCH_SIZE, shuffle=True,drop_last=True)

# %%
LOAD = True
LEARNING_RATE = 0.01
SEED = 7777
torch.manual_seed(SEED)
if device == 'cuda':
    torch.cuda.manual_seed_all(SEED)
model = n_net()
model.zero_grad()
loss_function = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(),lr=LEARNING_RATE)
TOTAL_BATCH = len(dataset_1_loader)
EPOCHS = 1000
loss_list = []
accuracy_list = []
epoch = 0

# %%
PATH = os.path.join("Saves","pretrained_model.pt")
SAVE_INTERVAL = 5
if LOAD:
    check = torch.load(PATH)
    model.load_state_dict(check["model"])
    epoch = check["epoch"]
    accuracy_list = check["accuracy list"]
    loss_list = check["loss list"]
    optimizer.load_state_dict(check["optimizer"])

# %%
while epoch < EPOCHS:
    cost = 0
    for image, label in dataset_1_loader:
        image = image.reshape(BATCH_SIZE,784)
        optimizer.zero_grad()
        predicted = model.forward(image)
        loss = loss_function(predicted,label)
        loss.backward()
        optimizer.step()
        cost+=loss
    with torch.no_grad():
        total = 0
        correct = 0
        for image, label in dataset_2_loader:
            image = image.reshape(BATCH_SIZE,784)
            out = model(image)
            _,predict = torch.max(out.data, 1)
            total += label.size(0)
            correct += (predict==label).sum()
    average_cost = cost/TOTAL_BATCH
    accuracy = 100*correct/total
    loss_list.append(average_cost.detach().numpy())
    accuracy_list.append(accuracy)
    epoch+=1
    print("epoch : {} | loss : {:.6f}" .format(epoch, average_cost))
    print("Accuracy : {:.2f}".format(accuracy))
    print("---------------------")
    if epoch%5 ==0:
        torch.save({"epoch":epoch,"loss list":loss_list,"accuracy list":accuracy_list,"model":model.state_dict(),"optimizer":optimizer.state_dict()},PATH)
# Out:
# epoch : 101 | loss : 0.058606
# Accuracy : 97.53
# ---------------------
# epoch : 102 | loss : 0.057835
# Accuracy : 97.56
# ---------------------
# epoch : 103 | loss : 0.057212
# Accuracy : 97.52
# ---------------------
# epoch : 104 | loss : 0.056527
# Accuracy : 97.51
# ---------------------
# epoch : 105 | loss : 0.055816
# Accuracy : 97.56
# ---------------------
# epoch : 106 | loss : 0.055315
# Accuracy : 97.58
# ---------------------
# epoch : 107 | loss : 0.054693
# Accuracy : 97.48
# ---------------------
# epoch : 108 | loss : 0.054071
# Accuracy : 97.62
# ---------------------
# epoch : 109 | loss : 0.053433
# Accuracy : 97.60
# ---------------------
# epoch : 110 | loss : 0.052852
# Accuracy : 97.61
# ---------------------
# epoch : 111 | loss : 0.052186
# Accuracy : 97.66
# ---------------------
# epoch : 112 | loss : 0.051474
# Accuracy : 97.60
# ---------------------
# epoch : 113 | loss : 0.051101
# Accuracy : 97.66
# ---------------------
# epoch : 114 | loss : 0.050393
# Accuracy : 97.61
# ---------------------
# epoch : 115 | loss : 0.049849
# Accuracy : 97.60
# ---------------------
# epoch : 116 | loss : 0.049331
# Accuracy : 97.60
# ---------------------
# epoch : 117 | loss : 0.048759
# Accuracy : 97.64
# ---------------------
# epoch : 118 | loss : 0.048090
# Accuracy : 97.57
# ---------------------
# epoch : 119 | loss : 0.047617
# Accuracy : 97.59
# ---------------------
# epoch : 120 | loss : 0.047183
# Accuracy : 97.67
# ---------------------
# epoch : 121 | loss : 0.046657
# Accuracy : 97.63
# ---------------------
# epoch : 122 | loss : 0.046083
# Accuracy : 97.66
# ---------------------
# epoch : 123 | loss : 0.045660
# Accuracy : 97.67
# ---------------------
# epoch : 124 | loss : 0.045044
# Accuracy : 97.68
# ---------------------
# epoch : 125 | loss : 0.044725
# Accuracy : 97.75
# ---------------------
# epoch : 126 | loss : 0.044102
# Accuracy : 97.64
# ---------------------
# epoch : 127 | loss : 0.043628
# Accuracy : 97.71
# ---------------------
# epoch : 128 | loss : 0.043077
# Accuracy : 97.64
# ---------------------
# epoch : 129 | loss : 0.042697
# Accuracy : 97.65
# ---------------------
# epoch : 130 | loss : 0.042183
# Accuracy : 97.64
# ---------------------
# epoch : 131 | loss : 0.041833
# Accuracy : 97.70
# ---------------------
# epoch : 132 | loss : 0.041117
# Accuracy : 97.68
# ---------------------
# epoch : 133 | loss : 0.040817
# Accuracy : 97.73
# ---------------------
# epoch : 134 | loss : 0.040463
# Accuracy : 97.70
# ---------------------
# epoch : 135 | loss : 0.039918
# Accuracy : 97.67
# ---------------------
# epoch : 136 | loss : 0.039506
# Accuracy : 97.70
# ---------------------
# epoch : 137 | loss : 0.039177
# Accuracy : 97.72
# ---------------------
# epoch : 138 | loss : 0.038671
# Accuracy : 97.82
# ---------------------
# epoch : 139 | loss : 0.038354
# Accuracy : 97.69
# ---------------------
# epoch : 140 | loss : 0.037870
# Accuracy : 97.71
# ---------------------
# epoch : 141 | loss : 0.037455
# Accuracy : 97.71
# ---------------------
# epoch : 142 | loss : 0.037180
# Accuracy : 97.72
# ---------------------
# epoch : 143 | loss : 0.036728
# Accuracy : 97.65
# ---------------------
# epoch : 144 | loss : 0.036440
# Accuracy : 97.75
# ---------------------
# epoch : 145 | loss : 0.035999
# Accuracy : 97.73
# ---------------------
# epoch : 146 | loss : 0.035588
# Accuracy : 97.74
# ---------------------
# epoch : 147 | loss : 0.035114
# Accuracy : 97.71
# ---------------------
# epoch : 148 | loss : 0.034884
# Accuracy : 97.75
# ---------------------
# epoch : 149 | loss : 0.034422
# Accuracy : 97.79
# ---------------------
# epoch : 150 | loss : 0.034137
# Accuracy : 97.72
# ---------------------
# epoch : 151 | loss : 0.033699
# Accuracy : 97.71
# ---------------------
# epoch : 152 | loss : 0.033438
# Accuracy : 97.77
# ---------------------
# epoch : 153 | loss : 0.033149
# Accuracy : 97.77
# ---------------------
# epoch : 154 | loss : 0.032694
# Accuracy : 97.76
# ---------------------
# epoch : 155 | loss : 0.032486
# Accuracy : 97.77
# ---------------------
# epoch : 156 | loss : 0.032065
# Accuracy : 97.72
# ---------------------
# epoch : 157 | loss : 0.031709
# Accuracy : 97.74
# ---------------------
# epoch : 158 | loss : 0.031469
# Accuracy : 97.72
# ---------------------
# epoch : 159 | loss : 0.031109
# Accuracy : 97.75
# ---------------------
# epoch : 160 | loss : 0.030775
# Accuracy : 97.80
# ---------------------
# epoch : 161 | loss : 0.030441
# Accuracy : 97.77
# ---------------------
# epoch : 162 | loss : 0.030112
# Accuracy : 97.77
# ---------------------
# epoch : 163 | loss : 0.029807
# Accuracy : 97.74
# ---------------------
# epoch : 164 | loss : 0.029517
# Accuracy : 97.81
# ---------------------
# epoch : 165 | loss : 0.029174
# Accuracy : 97.77
# ---------------------
# epoch : 166 | loss : 0.028838
# Accuracy : 97.78
# ---------------------
# epoch : 167 | loss : 0.028590
# Accuracy : 97.80
# ---------------------
# epoch : 168 | loss : 0.028249
# Accuracy : 97.80
# ---------------------
# epoch : 169 | loss : 0.027922
# Accuracy : 97.81
# ---------------------
# epoch : 170 | loss : 0.027794
# Accuracy : 97.81
# ---------------------
# epoch : 171 | loss : 0.027434
# Accuracy : 97.82
# ---------------------
# epoch : 172 | loss : 0.027133
# Accuracy : 97.83
# ---------------------
# epoch : 173 | loss : 0.026841
# Accuracy : 97.76
# ---------------------
# epoch : 174 | loss : 0.026639
# Accuracy : 97.79
# ---------------------
# epoch : 175 | loss : 0.026275
# Accuracy : 97.83
# ---------------------
# epoch : 176 | loss : 0.026042
# Accuracy : 97.82
# ---------------------
# epoch : 177 | loss : 0.025738
# Accuracy : 97.83
# ---------------------
# epoch : 178 | loss : 0.025529
# Accuracy : 97.79
# ---------------------
# epoch : 179 | loss : 0.025293
# Accuracy : 97.77
# ---------------------
# epoch : 180 | loss : 0.024940
# Accuracy : 97.79
# ---------------------
# epoch : 181 | loss : 0.024817
# Accuracy : 97.82
# ---------------------
# epoch : 182 | loss : 0.024564
# Accuracy : 97.78
# ---------------------
# epoch : 183 | loss : 0.024287
# Accuracy : 97.80
# ---------------------
# epoch : 184 | loss : 0.024047
# Accuracy : 97.82
# ---------------------
# epoch : 185 | loss : 0.023844
# Accuracy : 97.83
# ---------------------
# epoch : 186 | loss : 0.023574
# Accuracy : 97.82
# ---------------------
# epoch : 187 | loss : 0.023343
# Accuracy : 97.81
# ---------------------
# epoch : 188 | loss : 0.023104
# Accuracy : 97.86
# ---------------------
# epoch : 189 | loss : 0.022921
# Accuracy : 97.83
# ---------------------
# epoch : 190 | loss : 0.022653
# Accuracy : 97.86
# ---------------------
# epoch : 191 | loss : 0.022410
# Accuracy : 97.86
# ---------------------
# epoch : 192 | loss : 0.022231
# Accuracy : 97.83
# ---------------------
# epoch : 193 | loss : 0.021980
# Accuracy : 97.81
# ---------------------
# epoch : 194 | loss : 0.021726
# Accuracy : 97.81
# ---------------------
# epoch : 195 | loss : 0.021578
# Accuracy : 97.87
# ---------------------
# epoch : 196 | loss : 0.021280
# Accuracy : 97.79
# ---------------------
# epoch : 197 | loss : 0.021114
# Accuracy : 97.76
# ---------------------
# epoch : 198 | loss : 0.020950
# Accuracy : 97.79
# ---------------------
# epoch : 199 | loss : 0.020636
# Accuracy : 97.84
# ---------------------
# epoch : 200 | loss : 0.020456
# Accuracy : 97.82
# ---------------------
# epoch : 201 | loss : 0.020291
# Accuracy : 97.86
# ---------------------
# epoch : 202 | loss : 0.019993
# Accuracy : 97.83
# ---------------------
# epoch : 203 | loss : 0.019840
# Accuracy : 97.78
# ---------------------
# epoch : 204 | loss : 0.019721
# Accuracy : 97.85
# ---------------------
# epoch : 205 | loss : 0.019427
# Accuracy : 97.81
# ---------------------
# epoch : 206 | loss : 0.019408
# Accuracy : 97.82
# ---------------------
# epoch : 207 | loss : 0.019153
# Accuracy : 97.82
# ---------------------
# epoch : 208 | loss : 0.018928
# Accuracy : 97.89
# ---------------------
# epoch : 209 | loss : 0.018738
# Accuracy : 97.80
# ---------------------
# epoch : 210 | loss : 0.018573
# Accuracy : 97.84
# ---------------------
# epoch : 211 | loss : 0.018422
# Accuracy : 97.85
# ---------------------
# epoch : 212 | loss : 0.018153
# Accuracy : 97.85
# ---------------------
# epoch : 213 | loss : 0.017990
# Accuracy : 97.80
# ---------------------
# epoch : 214 | loss : 0.017823
# Accuracy : 97.80
# ---------------------
# epoch : 215 | loss : 0.017710
# Accuracy : 97.84
# ---------------------
# epoch : 216 | loss : 0.017497
# Accuracy : 97.92
# ---------------------
# epoch : 217 | loss : 0.017241
# Accuracy : 97.85
# ---------------------
# epoch : 218 | loss : 0.017190
# Accuracy : 97.84
# ---------------------
# epoch : 219 | loss : 0.017061
# Accuracy : 97.86
# ---------------------
# epoch : 220 | loss : 0.016850
# Accuracy : 97.84
# ---------------------
# epoch : 221 | loss : 0.016717
# Accuracy : 97.87
# ---------------------
# epoch : 222 | loss : 0.016503
# Accuracy : 97.76
# ---------------------
# epoch : 223 | loss : 0.016338
# Accuracy : 97.82
# ---------------------
# epoch : 224 | loss : 0.016172
# Accuracy : 97.91
# ---------------------
# epoch : 225 | loss : 0.016011
# Accuracy : 97.81
# ---------------------
# epoch : 226 | loss : 0.015899
# Accuracy : 97.79
# ---------------------
# epoch : 227 | loss : 0.015754
# Accuracy : 97.81
# ---------------------
# epoch : 228 | loss : 0.015597
# Accuracy : 97.87
# ---------------------
# epoch : 229 | loss : 0.015447
# Accuracy : 97.83
# ---------------------
# epoch : 230 | loss : 0.015238
# Accuracy : 97.77
# ---------------------
# epoch : 231 | loss : 0.015175
# Accuracy : 97.83
# ---------------------
# epoch : 232 | loss : 0.014965
# Accuracy : 97.84
# ---------------------
# epoch : 233 | loss : 0.014835
# Accuracy : 97.82
# ---------------------
# epoch : 234 | loss : 0.014633
# Accuracy : 97.84
# ---------------------
# epoch : 235 | loss : 0.014560
# Accuracy : 97.83
# ---------------------
# epoch : 236 | loss : 0.014441
# Accuracy : 97.86
# ---------------------
# epoch : 237 | loss : 0.014347
# Accuracy : 97.84
# ---------------------
# epoch : 238 | loss : 0.014180
# Accuracy : 97.82
# ---------------------
# epoch : 239 | loss : 0.014024
# Accuracy : 97.90
# ---------------------
# epoch : 240 | loss : 0.013920
# Accuracy : 97.86
# ---------------------
# epoch : 241 | loss : 0.013772
# Accuracy : 97.86
# ---------------------
# epoch : 242 | loss : 0.013655
# Accuracy : 97.83
# ---------------------
# epoch : 243 | loss : 0.013446
# Accuracy : 97.89
# ---------------------
# epoch : 244 | loss : 0.013348
# Accuracy : 97.79
# ---------------------
# epoch : 245 | loss : 0.013261
# Accuracy : 97.86
# ---------------------
# epoch : 246 | loss : 0.013153
# Accuracy : 97.86
# ---------------------
# epoch : 247 | loss : 0.012996
# Accuracy : 97.81
# ---------------------
# epoch : 248 | loss : 0.012933
# Accuracy : 97.83
# ---------------------
# epoch : 249 | loss : 0.012756
# Accuracy : 97.85
# ---------------------
# epoch : 250 | loss : 0.012649
# Accuracy : 97.85
# ---------------------
# epoch : 251 | loss : 0.012474
# Accuracy : 97.86
# ---------------------
# epoch : 252 | loss : 0.012416
# Accuracy : 97.86
# ---------------------
# epoch : 253 | loss : 0.012301
# Accuracy : 97.80
# ---------------------
# epoch : 254 | loss : 0.012169
# Accuracy : 97.85
# ---------------------
# epoch : 255 | loss : 0.012105
# Accuracy : 97.82
# ---------------------
# epoch : 256 | loss : 0.011994
# Accuracy : 97.81
# ---------------------
# epoch : 257 | loss : 0.011831
# Accuracy : 97.88
# ---------------------
# epoch : 258 | loss : 0.011795
# Accuracy : 97.79
# ---------------------
# epoch : 259 | loss : 0.011680
# Accuracy : 97.81
# ---------------------
# epoch : 260 | loss : 0.011460
# Accuracy : 97.81
# ---------------------
# epoch : 261 | loss : 0.011462
# Accuracy : 97.84
# ---------------------
# epoch : 262 | loss : 0.011349
# Accuracy : 97.79
# ---------------------
# epoch : 263 | loss : 0.011242
# Accuracy : 97.84
# ---------------------
# epoch : 264 | loss : 0.011129
# Accuracy : 97.82
# ---------------------
# epoch : 265 | loss : 0.011039
# Accuracy : 97.84
# ---------------------
# epoch : 266 | loss : 0.010959
# Accuracy : 97.83
# ---------------------
# epoch : 267 | loss : 0.010885
# Accuracy : 97.84
# ---------------------
# epoch : 268 | loss : 0.010748
# Accuracy : 97.82
# ---------------------
# epoch : 269 | loss : 0.010611
# Accuracy : 97.85
# ---------------------
# epoch : 270 | loss : 0.010540
# Accuracy : 97.85
# ---------------------
# epoch : 271 | loss : 0.010462
# Accuracy : 97.84
# ---------------------
# epoch : 272 | loss : 0.010383
# Accuracy : 97.79
# ---------------------
# epoch : 273 | loss : 0.010278
# Accuracy : 97.82
# ---------------------
# epoch : 274 | loss : 0.010216
# Accuracy : 97.84
# ---------------------
# epoch : 275 | loss : 0.010104
# Accuracy : 97.84
# ---------------------
# epoch : 276 | loss : 0.010009
# Accuracy : 97.80
# ---------------------
# epoch : 277 | loss : 0.009930
# Accuracy : 97.83
# ---------------------
# epoch : 278 | loss : 0.009868
# Accuracy : 97.81
# ---------------------
# epoch : 279 | loss : 0.009756
# Accuracy : 97.80
# ---------------------
# epoch : 280 | loss : 0.009651
# Accuracy : 97.77
# ---------------------
# epoch : 281 | loss : 0.009609
# Accuracy : 97.84
# ---------------------
# epoch : 282 | loss : 0.009498
# Accuracy : 97.77
# ---------------------
# epoch : 283 | loss : 0.009371
# Accuracy : 97.84
# ---------------------
# epoch : 284 | loss : 0.009324
# Accuracy : 97.79
# ---------------------
# epoch : 285 | loss : 0.009235
# Accuracy : 97.82
# ---------------------
# epoch : 286 | loss : 0.009173
# Accuracy : 97.81
# ---------------------
# epoch : 287 | loss : 0.009078
# Accuracy : 97.80
# ---------------------
# epoch : 288 | loss : 0.009025
# Accuracy : 97.78
# ---------------------
# epoch : 289 | loss : 0.008966
# Accuracy : 97.82
# ---------------------
# epoch : 290 | loss : 0.008861
# Accuracy : 97.84
# ---------------------
# epoch : 291 | loss : 0.008777
# Accuracy : 97.79
# ---------------------
# epoch : 292 | loss : 0.008662
# Accuracy : 97.82
# ---------------------
# epoch : 293 | loss : 0.008652
# Accuracy : 97.83
# ---------------------
# epoch : 294 | loss : 0.008566
# Accuracy : 97.82
# ---------------------
# epoch : 295 | loss : 0.008510
# Accuracy : 97.81
# ---------------------
# epoch : 296 | loss : 0.008429
# Accuracy : 97.84
# ---------------------
# epoch : 297 | loss : 0.008379
# Accuracy : 97.82
# ---------------------
# epoch : 298 | loss : 0.008298
# Accuracy : 97.83
# ---------------------
# epoch : 299 | loss : 0.008239
# Accuracy : 97.83
# ---------------------
# epoch : 300 | loss : 0.008154
# Accuracy : 97.85
# ---------------------
# epoch : 301 | loss : 0.008076
# Accuracy : 97.77
# ---------------------
# epoch : 302 | loss : 0.007988
# Accuracy : 97.82
# ---------------------
# epoch : 303 | loss : 0.007959
# Accuracy : 97.80
# ---------------------
# epoch : 304 | loss : 0.007908
# Accuracy : 97.80
# ---------------------
# epoch : 305 | loss : 0.007841
# Accuracy : 97.81
# ---------------------
# epoch : 306 | loss : 0.007749
# Accuracy : 97.83
# ---------------------
# epoch : 307 | loss : 0.007672
# Accuracy : 97.86
# ---------------------
# epoch : 308 | loss : 0.007644
# Accuracy : 97.81
# ---------------------
# epoch : 309 | loss : 0.007570
# Accuracy : 97.83
# ---------------------
# epoch : 310 | loss : 0.007504
# Accuracy : 97.82
# ---------------------
# epoch : 311 | loss : 0.007475
# Accuracy : 97.83
# ---------------------
# epoch : 312 | loss : 0.007381
# Accuracy : 97.76
# ---------------------
# epoch : 313 | loss : 0.007357
# Accuracy : 97.84
# ---------------------
# epoch : 314 | loss : 0.007256
# Accuracy : 97.83
# ---------------------
# epoch : 315 | loss : 0.007214
# Accuracy : 97.86
# ---------------------
# epoch : 316 | loss : 0.007155
# Accuracy : 97.83
# ---------------------
# epoch : 317 | loss : 0.007105
# Accuracy : 97.82
# ---------------------
# epoch : 318 | loss : 0.007054
# Accuracy : 97.84
# ---------------------
# epoch : 319 | loss : 0.006987
# Accuracy : 97.84
# ---------------------
# epoch : 320 | loss : 0.006934
# Accuracy : 97.84
# ---------------------
# epoch : 321 | loss : 0.006871
# Accuracy : 97.81
# ---------------------
# epoch : 322 | loss : 0.006794
# Accuracy : 97.81
# ---------------------
# epoch : 323 | loss : 0.006756
# Accuracy : 97.82
# ---------------------
# epoch : 324 | loss : 0.006716
# Accuracy : 97.83
# ---------------------
# epoch : 325 | loss : 0.006650
# Accuracy : 97.81
# ---------------------
# epoch : 326 | loss : 0.006621
# Accuracy : 97.85
# ---------------------
# epoch : 327 | loss : 0.006562
# Accuracy : 97.84
# ---------------------
# epoch : 328 | loss : 0.006514
# Accuracy : 97.84
# ---------------------
# epoch : 329 | loss : 0.006444
# Accuracy : 97.84
# ---------------------
# epoch : 330 | loss : 0.006407
# Accuracy : 97.86
# ---------------------
# epoch : 331 | loss : 0.006351
# Accuracy : 97.81
# ---------------------
# epoch : 332 | loss : 0.006287
# Accuracy : 97.82
# ---------------------
# epoch : 333 | loss : 0.006265
# Accuracy : 97.85
# ---------------------
# epoch : 334 | loss : 0.006229
# Accuracy : 97.82
# ---------------------
# epoch : 335 | loss : 0.006167
# Accuracy : 97.86
# ---------------------
# epoch : 336 | loss : 0.006134
# Accuracy : 97.83
# ---------------------
# epoch : 337 | loss : 0.006077
# Accuracy : 97.84
# ---------------------
# epoch : 338 | loss : 0.006034
# Accuracy : 97.85
# ---------------------
# epoch : 339 | loss : 0.005997
# Accuracy : 97.85
# ---------------------
# epoch : 340 | loss : 0.005970
# Accuracy : 97.86
# ---------------------
# epoch : 341 | loss : 0.005887
# Accuracy : 97.84
# ---------------------
# epoch : 342 | loss : 0.005874
# Accuracy : 97.83
# ---------------------
# epoch : 343 | loss : 0.005835
# Accuracy : 97.86
# ---------------------
# epoch : 344 | loss : 0.005769
# Accuracy : 97.80
# ---------------------
# epoch : 345 | loss : 0.005719
# Accuracy : 97.83
# ---------------------
# epoch : 346 | loss : 0.005703
# Accuracy : 97.82
# ---------------------
# epoch : 347 | loss : 0.005636
# Accuracy : 97.81
# ---------------------
# epoch : 348 | loss : 0.005603
# Accuracy : 97.83
# ---------------------
# epoch : 349 | loss : 0.005569
# Accuracy : 97.83
# ---------------------
# epoch : 350 | loss : 0.005498
# Accuracy : 97.81
# ---------------------
# epoch : 351 | loss : 0.005492
# Accuracy : 97.83
# ---------------------
# epoch : 352 | loss : 0.005450
# Accuracy : 97.81
# ---------------------
# epoch : 353 | loss : 0.005398
# Accuracy : 97.82
# ---------------------
# epoch : 354 | loss : 0.005359
# Accuracy : 97.82
# ---------------------
# epoch : 355 | loss : 0.005342
# Accuracy : 97.81
# ---------------------
# epoch : 356 | loss : 0.005315
# Accuracy : 97.84
# ---------------------
# epoch : 357 | loss : 0.005271
# Accuracy : 97.83
# ---------------------
# epoch : 358 | loss : 0.005202
# Accuracy : 97.83
# ---------------------
# epoch : 359 | loss : 0.005181
# Accuracy : 97.79
# ---------------------
# epoch : 360 | loss : 0.005163
# Accuracy : 97.81
# ---------------------
# epoch : 361 | loss : 0.005125
# Accuracy : 97.78
# ---------------------
# epoch : 362 | loss : 0.005077
# Accuracy : 97.84
# ---------------------
# epoch : 363 | loss : 0.005031
# Accuracy : 97.89
# ---------------------
# epoch : 364 | loss : 0.005025
# Accuracy : 97.84
# ---------------------
# epoch : 365 | loss : 0.004979
# Accuracy : 97.84
# ---------------------
# epoch : 366 | loss : 0.004943
# Accuracy : 97.83
# ---------------------
# epoch : 367 | loss : 0.004901
# Accuracy : 97.82
# ---------------------
# epoch : 368 | loss : 0.004881
# Accuracy : 97.85
# ---------------------
# epoch : 369 | loss : 0.004812
# Accuracy : 97.88
# ---------------------
# epoch : 370 | loss : 0.004790
# Accuracy : 97.84
# ---------------------
# epoch : 371 | loss : 0.004799
# Accuracy : 97.85
# ---------------------
# epoch : 372 | loss : 0.004749
# Accuracy : 97.82
# ---------------------
# epoch : 373 | loss : 0.004729
# Accuracy : 97.86
# ---------------------
# epoch : 374 | loss : 0.004675
# Accuracy : 97.83
# ---------------------
# epoch : 375 | loss : 0.004669
# Accuracy : 97.79
# ---------------------
# epoch : 376 | loss : 0.004617
# Accuracy : 97.83
# ---------------------
# epoch : 377 | loss : 0.004597
# Accuracy : 97.81
# ---------------------
# epoch : 378 | loss : 0.004556
# Accuracy : 97.86
# ---------------------
# epoch : 379 | loss : 0.004535
# Accuracy : 97.86
# ---------------------
# epoch : 380 | loss : 0.004514
# Accuracy : 97.83
# ---------------------
# epoch : 381 | loss : 0.004477
# Accuracy : 97.85
# ---------------------
# epoch : 382 | loss : 0.004458
# Accuracy : 97.81
# ---------------------
# epoch : 383 | loss : 0.004406
# Accuracy : 97.86
# ---------------------
# epoch : 384 | loss : 0.004400
# Accuracy : 97.84
# ---------------------
# epoch : 385 | loss : 0.004362
# Accuracy : 97.85
# ---------------------
# epoch : 386 | loss : 0.004327
# Accuracy : 97.82
# ---------------------
# epoch : 387 | loss : 0.004304
# Accuracy : 97.85
# ---------------------
# epoch : 388 | loss : 0.004281
# Accuracy : 97.86
# ---------------------
# epoch : 389 | loss : 0.004255
# Accuracy : 97.81
# ---------------------
# epoch : 390 | loss : 0.004242
# Accuracy : 97.81
# ---------------------
# epoch : 391 | loss : 0.004201
# Accuracy : 97.88
# ---------------------
# epoch : 392 | loss : 0.004179
# Accuracy : 97.83
# ---------------------
# epoch : 393 | loss : 0.004147
# Accuracy : 97.80
# ---------------------
# epoch : 394 | loss : 0.004126
# Accuracy : 97.80
# ---------------------
# epoch : 395 | loss : 0.004099
# Accuracy : 97.84
# ---------------------
# epoch : 396 | loss : 0.004057
# Accuracy : 97.83
# ---------------------
# epoch : 397 | loss : 0.004054
# Accuracy : 97.85
# ---------------------
# epoch : 398 | loss : 0.004031
# Accuracy : 97.83
# ---------------------
# epoch : 399 | loss : 0.003994
# Accuracy : 97.85
# ---------------------
# epoch : 400 | loss : 0.003980
# Accuracy : 97.84
# ---------------------
# epoch : 401 | loss : 0.003951
# Accuracy : 97.86
# ---------------------
# epoch : 402 | loss : 0.003936
# Accuracy : 97.87
# ---------------------
# epoch : 403 | loss : 0.003902
# Accuracy : 97.86
# ---------------------
# epoch : 404 | loss : 0.003886
# Accuracy : 97.85
# ---------------------
# epoch : 405 | loss : 0.003852
# Accuracy : 97.90
# ---------------------
# epoch : 406 | loss : 0.003836
# Accuracy : 97.85
# ---------------------
# epoch : 407 | loss : 0.003814
# Accuracy : 97.82
# ---------------------
# epoch : 408 | loss : 0.003793
# Accuracy : 97.89
# ---------------------
# epoch : 409 | loss : 0.003770
# Accuracy : 97.84
# ---------------------
# epoch : 410 | loss : 0.003737
# Accuracy : 97.84
# ---------------------
# epoch : 411 | loss : 0.003717
# Accuracy : 97.90
# ---------------------
# epoch : 412 | loss : 0.003701
# Accuracy : 97.83
# ---------------------
# epoch : 413 | loss : 0.003686
# Accuracy : 97.85
# ---------------------
# epoch : 414 | loss : 0.003672
# Accuracy : 97.82
# ---------------------
# epoch : 415 | loss : 0.003646
# Accuracy : 97.85
# ---------------------
# epoch : 416 | loss : 0.003616
# Accuracy : 97.83
# ---------------------
# epoch : 417 | loss : 0.003603
# Accuracy : 97.84
# ---------------------
# epoch : 418 | loss : 0.003565
# Accuracy : 97.85
# ---------------------
# epoch : 419 | loss : 0.003555
# Accuracy : 97.90
# ---------------------
# epoch : 420 | loss : 0.003524
# Accuracy : 97.85
# ---------------------
# epoch : 421 | loss : 0.003515
# Accuracy : 97.86
# ---------------------
# epoch : 422 | loss : 0.003495
# Accuracy : 97.84
# ---------------------
# epoch : 423 | loss : 0.003478
# Accuracy : 97.83
# ---------------------
# epoch : 424 | loss : 0.003455
# Accuracy : 97.83
# ---------------------
# epoch : 425 | loss : 0.003434
# Accuracy : 97.85
# ---------------------
# epoch : 426 | loss : 0.003425
# Accuracy : 97.83
# ---------------------
# epoch : 427 | loss : 0.003402
# Accuracy : 97.84
# ---------------------
# epoch : 428 | loss : 0.003368
# Accuracy : 97.82
# ---------------------
# epoch : 429 | loss : 0.003362
# Accuracy : 97.82
# ---------------------
# epoch : 430 | loss : 0.003344
# Accuracy : 97.88
# ---------------------
# epoch : 431 | loss : 0.003329
# Accuracy : 97.84
# ---------------------
# epoch : 432 | loss : 0.003305
# Accuracy : 97.83
# ---------------------
# epoch : 433 | loss : 0.003275
# Accuracy : 97.85
# ---------------------
# epoch : 434 | loss : 0.003262
# Accuracy : 97.85
# ---------------------
# epoch : 435 | loss : 0.003252
# Accuracy : 97.84
# ---------------------
# epoch : 436 | loss : 0.003232
# Accuracy : 97.87
# ---------------------
# epoch : 437 | loss : 0.003223
# Accuracy : 97.82
# ---------------------
# epoch : 438 | loss : 0.003198
# Accuracy : 97.83
# ---------------------
# epoch : 439 | loss : 0.003183
# Accuracy : 97.83
# ---------------------
# epoch : 440 | loss : 0.003166
# Accuracy : 97.87
# ---------------------
# epoch : 441 | loss : 0.003141
# Accuracy : 97.88
# ---------------------
# epoch : 442 | loss : 0.003133
# Accuracy : 97.87
# ---------------------
# epoch : 443 | loss : 0.003113
# Accuracy : 97.80
# ---------------------
# epoch : 444 | loss : 0.003097
# Accuracy : 97.87
# ---------------------
# epoch : 445 | loss : 0.003085
# Accuracy : 97.87
# ---------------------
# epoch : 446 | loss : 0.003067
# Accuracy : 97.86
# ---------------------
# epoch : 447 | loss : 0.003047
# Accuracy : 97.87
# ---------------------
# epoch : 448 | loss : 0.003035
# Accuracy : 97.87
# ---------------------
# epoch : 449 | loss : 0.003014
# Accuracy : 97.83
# ---------------------
# epoch : 450 | loss : 0.002996
# Accuracy : 97.86
# ---------------------
# epoch : 451 | loss : 0.002994
# Accuracy : 97.82
# ---------------------
# epoch : 452 | loss : 0.002983
# Accuracy : 97.86
# ---------------------
# epoch : 453 | loss : 0.002956
# Accuracy : 97.87
# ---------------------
# epoch : 454 | loss : 0.002943
# Accuracy : 97.82
# ---------------------
# epoch : 455 | loss : 0.002927
# Accuracy : 97.85
# ---------------------
# epoch : 456 | loss : 0.002915
# Accuracy : 97.86
# ---------------------
# epoch : 457 | loss : 0.002885
# Accuracy : 97.85
# ---------------------
# epoch : 458 | loss : 0.002884
# Accuracy : 97.87
# ---------------------
# epoch : 459 | loss : 0.002871
# Accuracy : 97.86
# ---------------------
# epoch : 460 | loss : 0.002852
# Accuracy : 97.90
# ---------------------
# epoch : 461 | loss : 0.002839
# Accuracy : 97.85
# ---------------------
# epoch : 462 | loss : 0.002830
# Accuracy : 97.83
# ---------------------
# epoch : 463 | loss : 0.002810
# Accuracy : 97.86
# ---------------------
# epoch : 464 | loss : 0.002786
# Accuracy : 97.85
# ---------------------
# epoch : 465 | loss : 0.002781
# Accuracy : 97.86
# ---------------------
# epoch : 466 | loss : 0.002768
# Accuracy : 97.88
# ---------------------
# epoch : 467 | loss : 0.002745
# Accuracy : 97.87
# ---------------------
# epoch : 468 | loss : 0.002748
# Accuracy : 97.85
# ---------------------
# epoch : 469 | loss : 0.002721
# Accuracy : 97.86
# ---------------------
# epoch : 470 | loss : 0.002715
# Accuracy : 97.85
# ---------------------
# epoch : 471 | loss : 0.002700
# Accuracy : 97.88
# ---------------------
# epoch : 472 | loss : 0.002688
# Accuracy : 97.88
# ---------------------
# epoch : 473 | loss : 0.002674
# Accuracy : 97.84
# ---------------------
# epoch : 474 | loss : 0.002665
# Accuracy : 97.83
# ---------------------
# epoch : 475 | loss : 0.002646
# Accuracy : 97.83
# ---------------------
# epoch : 476 | loss : 0.002632
# Accuracy : 97.84
# ---------------------
# epoch : 477 | loss : 0.002614
# Accuracy : 97.82
# ---------------------
# epoch : 478 | loss : 0.002599
# Accuracy : 97.90
# ---------------------
# epoch : 479 | loss : 0.002604
# Accuracy : 97.85
# ---------------------
# epoch : 480 | loss : 0.002585
# Accuracy : 97.92
# ---------------------
# epoch : 481 | loss : 0.002571
# Accuracy : 97.87
# ---------------------
# epoch : 482 | loss : 0.002564
# Accuracy : 97.87
# ---------------------
# epoch : 483 | loss : 0.002547
# Accuracy : 97.83
# ---------------------
# epoch : 484 | loss : 0.002545
# Accuracy : 97.86
# ---------------------
# epoch : 485 | loss : 0.002530
# Accuracy : 97.87
# ---------------------
# epoch : 486 | loss : 0.002511
# Accuracy : 97.87
# ---------------------
# epoch : 487 | loss : 0.002506
# Accuracy : 97.86
# ---------------------
# epoch : 488 | loss : 0.002490
# Accuracy : 97.89
# ---------------------
# epoch : 489 | loss : 0.002481
# Accuracy : 97.86
# ---------------------
# epoch : 490 | loss : 0.002472
# Accuracy : 97.90
# ---------------------
# epoch : 491 | loss : 0.002452
# Accuracy : 97.87
# ---------------------
# epoch : 492 | loss : 0.002444
# Accuracy : 97.88
# ---------------------
# epoch : 493 | loss : 0.002433
# Accuracy : 97.89
# ---------------------
# epoch : 494 | loss : 0.002417
# Accuracy : 97.87
# ---------------------
# epoch : 495 | loss : 0.002406
# Accuracy : 97.83
# ---------------------
# epoch : 496 | loss : 0.002405
# Accuracy : 97.85
# ---------------------
# epoch : 497 | loss : 0.002373
# Accuracy : 97.85
# ---------------------
# epoch : 498 | loss : 0.002384
# Accuracy : 97.85
# ---------------------
# epoch : 499 | loss : 0.002371
# Accuracy : 97.87
# ---------------------
# epoch : 500 | loss : 0.002361
# Accuracy : 97.85
# ---------------------
# epoch : 501 | loss : 0.002338
# Accuracy : 97.87
# ---------------------
# epoch : 502 | loss : 0.002339
# Accuracy : 97.89
# ---------------------
# epoch : 503 | loss : 0.002326
# Accuracy : 97.89
# ---------------------
# epoch : 504 | loss : 0.002321
# Accuracy : 97.83
# ---------------------
# epoch : 505 | loss : 0.002314
# Accuracy : 97.86
# ---------------------
# epoch : 506 | loss : 0.002300
# Accuracy : 97.87
# ---------------------
# epoch : 507 | loss : 0.002287
# Accuracy : 97.85
# ---------------------
# epoch : 508 | loss : 0.002276
# Accuracy : 97.88
# ---------------------
# epoch : 509 | loss : 0.002259
# Accuracy : 97.88
# ---------------------
# epoch : 510 | loss : 0.002256
# Accuracy : 97.87
# ---------------------
# epoch : 511 | loss : 0.002242
# Accuracy : 97.86
# ---------------------
# epoch : 512 | loss : 0.002235
# Accuracy : 97.86
# ---------------------
# epoch : 513 | loss : 0.002227
# Accuracy : 97.85
# ---------------------
# epoch : 514 | loss : 0.002218
# Accuracy : 97.88
# ---------------------
# epoch : 515 | loss : 0.002210
# Accuracy : 97.87
# ---------------------
# epoch : 516 | loss : 0.002197
# Accuracy : 97.87
# ---------------------
# epoch : 517 | loss : 0.002182
# Accuracy : 97.88
# ---------------------
# epoch : 518 | loss : 0.002185
# Accuracy : 97.87
# ---------------------
# epoch : 519 | loss : 0.002169
# Accuracy : 97.85
# ---------------------
# epoch : 520 | loss : 0.002163
# Accuracy : 97.85
# ---------------------
# epoch : 521 | loss : 0.002155
# Accuracy : 97.86
# ---------------------
# epoch : 522 | loss : 0.002148
# Accuracy : 97.85
# ---------------------
# epoch : 523 | loss : 0.002136
# Accuracy : 97.83
# ---------------------
# epoch : 524 | loss : 0.002121
# Accuracy : 97.86
# ---------------------
# epoch : 525 | loss : 0.002120
# Accuracy : 97.87
# ---------------------
# epoch : 526 | loss : 0.002114
# Accuracy : 97.88
# ---------------------
# epoch : 527 | loss : 0.002101
# Accuracy : 97.86
# ---------------------
# epoch : 528 | loss : 0.002085
# Accuracy : 97.89
# ---------------------
# epoch : 529 | loss : 0.002079
# Accuracy : 97.85
# ---------------------
# epoch : 530 | loss : 0.002075
# Accuracy : 97.89
# ---------------------
# epoch : 531 | loss : 0.002067
# Accuracy : 97.87
# ---------------------
# epoch : 532 | loss : 0.002058
# Accuracy : 97.81
# ---------------------
# epoch : 533 | loss : 0.002055
# Accuracy : 97.87
# ---------------------
# epoch : 534 | loss : 0.002042
# Accuracy : 97.85
# ---------------------
# epoch : 535 | loss : 0.002032
# Accuracy : 97.89
# ---------------------
# epoch : 536 | loss : 0.002029
# Accuracy : 97.87
# ---------------------
# epoch : 537 | loss : 0.002012
# Accuracy : 97.89
# ---------------------
# epoch : 538 | loss : 0.002006
# Accuracy : 97.90
# ---------------------
# epoch : 539 | loss : 0.002003
# Accuracy : 97.87
# ---------------------
# epoch : 540 | loss : 0.001987
# Accuracy : 97.89
# ---------------------
# epoch : 541 | loss : 0.001988
# Accuracy : 97.91
# ---------------------
# epoch : 542 | loss : 0.001977
# Accuracy : 97.87
# ---------------------
# epoch : 543 | loss : 0.001958
# Accuracy : 97.89
# ---------------------
# epoch : 544 | loss : 0.001963
# Accuracy : 97.86
# ---------------------
# epoch : 545 | loss : 0.001952
# Accuracy : 97.82
# ---------------------
# epoch : 546 | loss : 0.001947
# Accuracy : 97.89
# ---------------------
# epoch : 547 | loss : 0.001939
# Accuracy : 97.88
# ---------------------
# epoch : 548 | loss : 0.001925
# Accuracy : 97.87
# ---------------------
# epoch : 549 | loss : 0.001921
# Accuracy : 97.86
# ---------------------
# epoch : 550 | loss : 0.001914
# Accuracy : 97.87
# ---------------------
# epoch : 551 | loss : 0.001911
# Accuracy : 97.85
# ---------------------
# epoch : 552 | loss : 0.001903
# Accuracy : 97.85
# ---------------------
# epoch : 553 | loss : 0.001895
# Accuracy : 97.87
# ---------------------
# epoch : 554 | loss : 0.001884
# Accuracy : 97.87
# ---------------------
# epoch : 555 | loss : 0.001876
# Accuracy : 97.84
# ---------------------
# epoch : 556 | loss : 0.001874
# Accuracy : 97.87
# ---------------------
# epoch : 557 | loss : 0.001864
# Accuracy : 97.90
# ---------------------
# epoch : 558 | loss : 0.001859
# Accuracy : 97.88
# ---------------------
# epoch : 559 | loss : 0.001851
# Accuracy : 97.88
# ---------------------
# epoch : 560 | loss : 0.001842
# Accuracy : 97.87
# ---------------------
# epoch : 561 | loss : 0.001839
# Accuracy : 97.89
# ---------------------
# epoch : 562 | loss : 0.001833
# Accuracy : 97.89
# ---------------------
# epoch : 563 | loss : 0.001822
# Accuracy : 97.87
# ---------------------
# epoch : 564 | loss : 0.001819
# Accuracy : 97.88
# ---------------------
# epoch : 565 | loss : 0.001809
# Accuracy : 97.89
# ---------------------
# epoch : 566 | loss : 0.001800
# Accuracy : 97.89
# ---------------------
# epoch : 567 | loss : 0.001797
# Accuracy : 97.90
# ---------------------
# epoch : 568 | loss : 0.001789
# Accuracy : 97.92
# ---------------------
# epoch : 569 | loss : 0.001777
# Accuracy : 97.86
# ---------------------
# epoch : 570 | loss : 0.001774
# Accuracy : 97.86
# ---------------------
# epoch : 571 | loss : 0.001769
# Accuracy : 97.89
# ---------------------
# epoch : 572 | loss : 0.001760
# Accuracy : 97.88
# ---------------------
# epoch : 573 | loss : 0.001756
# Accuracy : 97.86
# ---------------------
# epoch : 574 | loss : 0.001751
# Accuracy : 97.85
# ---------------------
# epoch : 575 | loss : 0.001745
# Accuracy : 97.88
# ---------------------
# epoch : 576 | loss : 0.001737
# Accuracy : 97.87
# ---------------------
# epoch : 577 | loss : 0.001731
# Accuracy : 97.87
# ---------------------
# epoch : 578 | loss : 0.001724
# Accuracy : 97.85
# ---------------------
# epoch : 579 | loss : 0.001720
# Accuracy : 97.87
# ---------------------
# epoch : 580 | loss : 0.001711
# Accuracy : 97.90
# ---------------------
# epoch : 581 | loss : 0.001706
# Accuracy : 97.92
# ---------------------
# epoch : 582 | loss : 0.001700
# Accuracy : 97.86
# ---------------------
# epoch : 583 | loss : 0.001692
# Accuracy : 97.87
# ---------------------
# epoch : 584 | loss : 0.001686
# Accuracy : 97.88
# ---------------------
# epoch : 585 | loss : 0.001676
# Accuracy : 97.88
# ---------------------
# epoch : 586 | loss : 0.001679
# Accuracy : 97.90
# ---------------------
# epoch : 587 | loss : 0.001671
# Accuracy : 97.89
# ---------------------
# epoch : 588 | loss : 0.001665
# Accuracy : 97.87
# ---------------------
# epoch : 589 | loss : 0.001659
# Accuracy : 97.89
# ---------------------
# epoch : 590 | loss : 0.001652
# Accuracy : 97.88
# ---------------------
# epoch : 591 | loss : 0.001647
# Accuracy : 97.89
# ---------------------
# epoch : 592 | loss : 0.001642
# Accuracy : 97.88
# ---------------------
# epoch : 593 | loss : 0.001634
# Accuracy : 97.90
# ---------------------
# epoch : 594 | loss : 0.001627
# Accuracy : 97.88
# ---------------------
# epoch : 595 | loss : 0.001625
# Accuracy : 97.88
# ---------------------
# epoch : 596 | loss : 0.001618
# Accuracy : 97.88
# ---------------------
# epoch : 597 | loss : 0.001613
# Accuracy : 97.86
# ---------------------
# epoch : 598 | loss : 0.001603
# Accuracy : 97.87
# ---------------------
# epoch : 599 | loss : 0.001601
# Accuracy : 97.87
# ---------------------
# epoch : 600 | loss : 0.001595
# Accuracy : 97.87
# ---------------------
# epoch : 601 | loss : 0.001589
# Accuracy : 97.87
# ---------------------
# epoch : 602 | loss : 0.001585
# Accuracy : 97.88
# ---------------------
# epoch : 603 | loss : 0.001580
# Accuracy : 97.90
# ---------------------
# epoch : 604 | loss : 0.001576
# Accuracy : 97.89
# ---------------------
# epoch : 605 | loss : 0.001569
# Accuracy : 97.89
# ---------------------
# epoch : 606 | loss : 0.001563
# Accuracy : 97.88
# ---------------------
# epoch : 607 | loss : 0.001559
# Accuracy : 97.88
# ---------------------
# epoch : 608 | loss : 0.001554
# Accuracy : 97.88
# ---------------------
# epoch : 609 | loss : 0.001549
# Accuracy : 97.87
# ---------------------
# epoch : 610 | loss : 0.001543
# Accuracy : 97.86
# ---------------------
# epoch : 611 | loss : 0.001534
# Accuracy : 97.87
# ---------------------
# epoch : 612 | loss : 0.001534
# Accuracy : 97.86
# ---------------------
# epoch : 613 | loss : 0.001526
# Accuracy : 97.89
# ---------------------
# epoch : 614 | loss : 0.001523
# Accuracy : 97.89
# ---------------------
# epoch : 615 | loss : 0.001519
# Accuracy : 97.89
# ---------------------
# epoch : 616 | loss : 0.001512
# Accuracy : 97.89
# ---------------------
# epoch : 617 | loss : 0.001506
# Accuracy : 97.88
# ---------------------
# epoch : 618 | loss : 0.001502
# Accuracy : 97.86
# ---------------------
# epoch : 619 | loss : 0.001496
# Accuracy : 97.86
# ---------------------
# epoch : 620 | loss : 0.001492
# Accuracy : 97.85
# ---------------------
# epoch : 621 | loss : 0.001482
# Accuracy : 97.88
# ---------------------
# epoch : 622 | loss : 0.001484
# Accuracy : 97.86
# ---------------------
# epoch : 623 | loss : 0.001476
# Accuracy : 97.87
# ---------------------
# epoch : 624 | loss : 0.001475
# Accuracy : 97.88
# ---------------------
# epoch : 625 | loss : 0.001467
# Accuracy : 97.93
# ---------------------
# epoch : 626 | loss : 0.001464
# Accuracy : 97.86
# ---------------------
# epoch : 627 | loss : 0.001459
# Accuracy : 97.86
# ---------------------
# epoch : 628 | loss : 0.001455
# Accuracy : 97.88
# ---------------------
# epoch : 629 | loss : 0.001450
# Accuracy : 97.86
# ---------------------
# epoch : 630 | loss : 0.001446
# Accuracy : 97.89
# ---------------------
# epoch : 631 | loss : 0.001441
# Accuracy : 97.88
# ---------------------
# epoch : 632 | loss : 0.001430
# Accuracy : 97.87
# ---------------------
# epoch : 633 | loss : 0.001431
# Accuracy : 97.87
# ---------------------
# epoch : 634 | loss : 0.001426
# Accuracy : 97.88
# ---------------------
# epoch : 635 | loss : 0.001423
# Accuracy : 97.86
# ---------------------
# epoch : 636 | loss : 0.001418
# Accuracy : 97.86
# ---------------------
# epoch : 637 | loss : 0.001413
# Accuracy : 97.88
# ---------------------
# epoch : 638 | loss : 0.001409
# Accuracy : 97.89
# ---------------------
# epoch : 639 | loss : 0.001404
# Accuracy : 97.88
# ---------------------
# epoch : 640 | loss : 0.001401
# Accuracy : 97.90
# ---------------------
# epoch : 641 | loss : 0.001397
# Accuracy : 97.88
# ---------------------
# epoch : 642 | loss : 0.001392
# Accuracy : 97.88
# ---------------------
# epoch : 643 | loss : 0.001385
# Accuracy : 97.90
# ---------------------
# epoch : 644 | loss : 0.001382
# Accuracy : 97.85
# ---------------------
# epoch : 645 | loss : 0.001379
# Accuracy : 97.89
# ---------------------
# epoch : 646 | loss : 0.001374
# Accuracy : 97.86
# ---------------------
# epoch : 647 | loss : 0.001369
# Accuracy : 97.86
# ---------------------
# epoch : 648 | loss : 0.001363
# Accuracy : 97.87
# ---------------------
# epoch : 649 | loss : 0.001360
# Accuracy : 97.88
# ---------------------
# epoch : 650 | loss : 0.001356
# Accuracy : 97.86
# ---------------------
# epoch : 651 | loss : 0.001352
# Accuracy : 97.85
# ---------------------
# epoch : 652 | loss : 0.001346
# Accuracy : 97.89
# ---------------------
# epoch : 653 | loss : 0.001346
# Accuracy : 97.86
# ---------------------
# epoch : 654 | loss : 0.001341
# Accuracy : 97.90
# ---------------------
# epoch : 655 | loss : 0.001337
# Accuracy : 97.89
# ---------------------
# epoch : 656 | loss : 0.001334
# Accuracy : 97.88
# ---------------------
# epoch : 657 | loss : 0.001324
# Accuracy : 97.87
# ---------------------
# epoch : 658 | loss : 0.001324
# Accuracy : 97.89
# ---------------------
# epoch : 659 | loss : 0.001321
# Accuracy : 97.88
# ---------------------
# epoch : 660 | loss : 0.001316
# Accuracy : 97.85
# ---------------------
# epoch : 661 | loss : 0.001312
# Accuracy : 97.87
# ---------------------
# epoch : 662 | loss : 0.001307
# Accuracy : 97.82
# ---------------------
# epoch : 663 | loss : 0.001307
# Accuracy : 97.90
# ---------------------
# epoch : 664 | loss : 0.001299
# Accuracy : 97.89
# ---------------------
# epoch : 665 | loss : 0.001298
# Accuracy : 97.87
# ---------------------
# epoch : 666 | loss : 0.001294
# Accuracy : 97.88
# ---------------------
# epoch : 667 | loss : 0.001289
# Accuracy : 97.83
# ---------------------
# epoch : 668 | loss : 0.001286
# Accuracy : 97.84
# ---------------------
# epoch : 669 | loss : 0.001281
# Accuracy : 97.86
# ---------------------
# epoch : 670 | loss : 0.001279
# Accuracy : 97.87
# ---------------------
# epoch : 671 | loss : 0.001272
# Accuracy : 97.88
# ---------------------
# epoch : 672 | loss : 0.001271
# Accuracy : 97.87
# ---------------------
# epoch : 673 | loss : 0.001267
# Accuracy : 97.88
# ---------------------
# epoch : 674 | loss : 0.001263
# Accuracy : 97.87
# ---------------------
# epoch : 675 | loss : 0.001257
# Accuracy : 97.87
# ---------------------
# epoch : 676 | loss : 0.001256
# Accuracy : 97.90
# ---------------------
# epoch : 677 | loss : 0.001254
# Accuracy : 97.85
# ---------------------
# epoch : 678 | loss : 0.001248
# Accuracy : 97.86
# ---------------------
# epoch : 679 | loss : 0.001241
# Accuracy : 97.86
# ---------------------
# epoch : 680 | loss : 0.001242
# Accuracy : 97.86
# ---------------------
# epoch : 681 | loss : 0.001238
# Accuracy : 97.90
# ---------------------
# epoch : 682 | loss : 0.001235
# Accuracy : 97.91
# ---------------------
# epoch : 683 | loss : 0.001230
# Accuracy : 97.87
# ---------------------
# epoch : 684 | loss : 0.001224
# Accuracy : 97.87
# ---------------------
# epoch : 685 | loss : 0.001223
# Accuracy : 97.87
# ---------------------
# epoch : 686 | loss : 0.001219
# Accuracy : 97.87
# ---------------------
# epoch : 687 | loss : 0.001218
# Accuracy : 97.88
# ---------------------
# epoch : 688 | loss : 0.001213
# Accuracy : 97.84
# ---------------------
# epoch : 689 | loss : 0.001209
# Accuracy : 97.87
# ---------------------
# epoch : 690 | loss : 0.001203
# Accuracy : 97.86
# ---------------------
# epoch : 691 | loss : 0.001204
# Accuracy : 97.89
# ---------------------
# epoch : 692 | loss : 0.001201
# Accuracy : 97.88
# ---------------------
# epoch : 693 | loss : 0.001194
# Accuracy : 97.87
# ---------------------
# epoch : 694 | loss : 0.001193
# Accuracy : 97.90
# ---------------------
# epoch : 695 | loss : 0.001190
# Accuracy : 97.88
# ---------------------
# epoch : 696 | loss : 0.001186
# Accuracy : 97.87
# ---------------------
# epoch : 697 | loss : 0.001183
# Accuracy : 97.87
# ---------------------
# epoch : 698 | loss : 0.001179
# Accuracy : 97.89
# ---------------------
# epoch : 699 | loss : 0.001177
# Accuracy : 97.87
# ---------------------
# epoch : 700 | loss : 0.001174
# Accuracy : 97.87
# ---------------------
# epoch : 701 | loss : 0.001171
# Accuracy : 97.87
# ---------------------
# epoch : 702 | loss : 0.001167
# Accuracy : 97.88
# ---------------------
# epoch : 703 | loss : 0.001166
# Accuracy : 97.86
# ---------------------
# epoch : 704 | loss : 0.001162
# Accuracy : 97.88
# ---------------------
# epoch : 705 | loss : 0.001154
# Accuracy : 97.86
# ---------------------
# epoch : 706 | loss : 0.001153
# Accuracy : 97.87
# ---------------------
# epoch : 707 | loss : 0.001150
# Accuracy : 97.87
# ---------------------
# epoch : 708 | loss : 0.001149
# Accuracy : 97.90
# ---------------------
# epoch : 709 | loss : 0.001144
# Accuracy : 97.85
# ---------------------
# epoch : 710 | loss : 0.001141
# Accuracy : 97.86
# ---------------------
# epoch : 711 | loss : 0.001135
# Accuracy : 97.88
# ---------------------
# epoch : 712 | loss : 0.001134
# Accuracy : 97.86
# ---------------------
# epoch : 713 | loss : 0.001133
# Accuracy : 97.88
# ---------------------
# epoch : 714 | loss : 0.001127
# Accuracy : 97.90
# ---------------------
# epoch : 715 | loss : 0.001126
# Accuracy : 97.89
# ---------------------
# epoch : 716 | loss : 0.001121
# Accuracy : 97.88
# ---------------------
# epoch : 717 | loss : 0.001119
# Accuracy : 97.89
# ---------------------
# epoch : 718 | loss : 0.001116
# Accuracy : 97.86
# ---------------------
# epoch : 719 | loss : 0.001111
# Accuracy : 97.86
# ---------------------
# epoch : 720 | loss : 0.001111
# Accuracy : 97.88
# ---------------------
# epoch : 721 | loss : 0.001107
# Accuracy : 97.87
# ---------------------
# epoch : 722 | loss : 0.001104
# Accuracy : 97.84
# ---------------------
# epoch : 723 | loss : 0.001098
# Accuracy : 97.86
# ---------------------
# epoch : 724 | loss : 0.001098
# Accuracy : 97.88
# ---------------------
# epoch : 725 | loss : 0.001098
# Accuracy : 97.86
# ---------------------
# epoch : 726 | loss : 0.001093
# Accuracy : 97.87
# ---------------------
# epoch : 727 | loss : 0.001090
# Accuracy : 97.88
# ---------------------
# epoch : 728 | loss : 0.001087
# Accuracy : 97.87
# ---------------------
# epoch : 729 | loss : 0.001084
# Accuracy : 97.89
# ---------------------
# epoch : 730 | loss : 0.001084
# Accuracy : 97.85
# ---------------------
# epoch : 731 | loss : 0.001080
# Accuracy : 97.91
# ---------------------
# epoch : 732 | loss : 0.001077
# Accuracy : 97.89
# ---------------------
# epoch : 733 | loss : 0.001075
# Accuracy : 97.89
# ---------------------
# epoch : 734 | loss : 0.001069
# Accuracy : 97.93
# ---------------------
# epoch : 735 | loss : 0.001068
# Accuracy : 97.88
# ---------------------
# epoch : 736 | loss : 0.001065
# Accuracy : 97.88
# ---------------------
# epoch : 737 | loss : 0.001063
# Accuracy : 97.87
# ---------------------
# epoch : 738 | loss : 0.001061
# Accuracy : 97.87
# ---------------------
# epoch : 739 | loss : 0.001058
# Accuracy : 97.86
# ---------------------
# epoch : 740 | loss : 0.001055
# Accuracy : 97.87
# ---------------------
# epoch : 741 | loss : 0.001052
# Accuracy : 97.87
# ---------------------
# epoch : 742 | loss : 0.001049
# Accuracy : 97.87
# ---------------------
# epoch : 743 | loss : 0.001046
# Accuracy : 97.90
# ---------------------
# epoch : 744 | loss : 0.001043
# Accuracy : 97.88
# ---------------------
# epoch : 745 | loss : 0.001042
# Accuracy : 97.90
# ---------------------
# epoch : 746 | loss : 0.001038
# Accuracy : 97.89
# ---------------------
# epoch : 747 | loss : 0.001036
# Accuracy : 97.87
# ---------------------
# epoch : 748 | loss : 0.001030
# Accuracy : 97.91
# ---------------------
# epoch : 749 | loss : 0.001033
# Accuracy : 97.85
# ---------------------
# epoch : 750 | loss : 0.001028
# Accuracy : 97.85
# ---------------------
# epoch : 751 | loss : 0.001027
# Accuracy : 97.86
# ---------------------
# epoch : 752 | loss : 0.001023
# Accuracy : 97.87
# ---------------------
# epoch : 753 | loss : 0.001020
# Accuracy : 97.88
# ---------------------
# epoch : 754 | loss : 0.001017
# Accuracy : 97.88
# ---------------------
# epoch : 755 | loss : 0.001015
# Accuracy : 97.88
# ---------------------
# epoch : 756 | loss : 0.001013
# Accuracy : 97.88
# ---------------------
# epoch : 757 | loss : 0.001011
# Accuracy : 97.87
# ---------------------
# epoch : 758 | loss : 0.001008
# Accuracy : 97.89
# ---------------------
# epoch : 759 | loss : 0.001007
# Accuracy : 97.86
# ---------------------
# epoch : 760 | loss : 0.001003
# Accuracy : 97.85
# ---------------------
# epoch : 761 | loss : 0.001001
# Accuracy : 97.86
# ---------------------
# epoch : 762 | loss : 0.000999
# Accuracy : 97.88
# ---------------------
# epoch : 763 | loss : 0.000993
# Accuracy : 97.88
# ---------------------
# epoch : 764 | loss : 0.000994
# Accuracy : 97.88
# ---------------------
# epoch : 765 | loss : 0.000991
# Accuracy : 97.88
# ---------------------
# epoch : 766 | loss : 0.000987
# Accuracy : 97.88
# ---------------------
# epoch : 767 | loss : 0.000987
# Accuracy : 97.83
# ---------------------
# epoch : 768 | loss : 0.000983
# Accuracy : 97.90
# ---------------------
# epoch : 769 | loss : 0.000981
# Accuracy : 97.89
# ---------------------
# epoch : 770 | loss : 0.000979
# Accuracy : 97.90
# ---------------------
# epoch : 771 | loss : 0.000977
# Accuracy : 97.85
# ---------------------
# epoch : 772 | loss : 0.000974
# Accuracy : 97.88
# ---------------------
# epoch : 773 | loss : 0.000971
# Accuracy : 97.89
# ---------------------
# epoch : 774 | loss : 0.000969
# Accuracy : 97.87
# ---------------------
# epoch : 775 | loss : 0.000967
# Accuracy : 97.88
# ---------------------
# epoch : 776 | loss : 0.000963
# Accuracy : 97.86
# ---------------------
# epoch : 777 | loss : 0.000962
# Accuracy : 97.86
# ---------------------
# epoch : 778 | loss : 0.000959
# Accuracy : 97.88
# ---------------------
# epoch : 779 | loss : 0.000958
# Accuracy : 97.87
# ---------------------
# epoch : 780 | loss : 0.000956
# Accuracy : 97.89
# ---------------------
# epoch : 781 | loss : 0.000953
# Accuracy : 97.89
# ---------------------
# epoch : 782 | loss : 0.000951
# Accuracy : 97.89
# ---------------------
# epoch : 783 | loss : 0.000949
# Accuracy : 97.87
# ---------------------
# epoch : 784 | loss : 0.000945
# Accuracy : 97.89
# ---------------------
# epoch : 785 | loss : 0.000944
# Accuracy : 97.86
# ---------------------
# epoch : 786 | loss : 0.000943
# Accuracy : 97.87
# ---------------------
# epoch : 787 | loss : 0.000941
# Accuracy : 97.89
# ---------------------
# epoch : 788 | loss : 0.000936
# Accuracy : 97.87
# ---------------------
# epoch : 789 | loss : 0.000932
# Accuracy : 97.91
# ---------------------
# epoch : 790 | loss : 0.000932
# Accuracy : 97.88
# ---------------------
# epoch : 791 | loss : 0.000931
# Accuracy : 97.90
# ---------------------
# epoch : 792 | loss : 0.000929
# Accuracy : 97.89
# ---------------------
# epoch : 793 | loss : 0.000927
# Accuracy : 97.89
# ---------------------
# epoch : 794 | loss : 0.000923
# Accuracy : 97.91
# ---------------------
# epoch : 795 | loss : 0.000922
# Accuracy : 97.85
# ---------------------
# epoch : 796 | loss : 0.000915
# Accuracy : 97.90
# ---------------------
# epoch : 797 | loss : 0.000919
# Accuracy : 97.90
# ---------------------
# epoch : 798 | loss : 0.000917
# Accuracy : 97.90
# ---------------------
# epoch : 799 | loss : 0.000915
# Accuracy : 97.87
# ---------------------
# epoch : 800 | loss : 0.000912
# Accuracy : 97.84
# ---------------------
# epoch : 801 | loss : 0.000911
# Accuracy : 97.86
# ---------------------
# epoch : 802 | loss : 0.000906
# Accuracy : 97.89
# ---------------------
# epoch : 803 | loss : 0.000905
# Accuracy : 97.90
# ---------------------
# epoch : 804 | loss : 0.000905
# Accuracy : 97.88
# ---------------------
# epoch : 805 | loss : 0.000900
# Accuracy : 97.90
# ---------------------
# epoch : 806 | loss : 0.000900
# Accuracy : 97.90
# ---------------------
# epoch : 807 | loss : 0.000896
# Accuracy : 97.90
# ---------------------
# epoch : 808 | loss : 0.000894
# Accuracy : 97.89
# ---------------------
# epoch : 809 | loss : 0.000894
# Accuracy : 97.87
# ---------------------
# epoch : 810 | loss : 0.000893
# Accuracy : 97.89
# ---------------------
# epoch : 811 | loss : 0.000890
# Accuracy : 97.87
# ---------------------
# epoch : 812 | loss : 0.000886
# Accuracy : 97.87
# ---------------------
# epoch : 813 | loss : 0.000884
# Accuracy : 97.91
# ---------------------
# epoch : 814 | loss : 0.000883
# Accuracy : 97.89
# ---------------------
# epoch : 815 | loss : 0.000881
# Accuracy : 97.88
# ---------------------
# epoch : 816 | loss : 0.000880
# Accuracy : 97.85
# ---------------------
# epoch : 817 | loss : 0.000877
# Accuracy : 97.89
# ---------------------
# epoch : 818 | loss : 0.000875
# Accuracy : 97.89
# ---------------------
# epoch : 819 | loss : 0.000873
# Accuracy : 97.87
# ---------------------
# epoch : 820 | loss : 0.000872
# Accuracy : 97.90
# ---------------------
# epoch : 821 | loss : 0.000870
# Accuracy : 97.88
# ---------------------
# epoch : 822 | loss : 0.000867
# Accuracy : 97.87
# ---------------------
# epoch : 823 | loss : 0.000864
# Accuracy : 97.88
# ---------------------
# epoch : 824 | loss : 0.000865
# Accuracy : 97.85
# ---------------------
# epoch : 825 | loss : 0.000861
# Accuracy : 97.89
# ---------------------
# epoch : 826 | loss : 0.000860
# Accuracy : 97.85
# ---------------------
# epoch : 827 | loss : 0.000857
# Accuracy : 97.83
# ---------------------
# epoch : 828 | loss : 0.000856
# Accuracy : 97.89
# ---------------------
# epoch : 829 | loss : 0.000854
# Accuracy : 97.88
# ---------------------
# epoch : 830 | loss : 0.000852
# Accuracy : 97.84
# ---------------------
# epoch : 831 | loss : 0.000851
# Accuracy : 97.86
# ---------------------
# epoch : 832 | loss : 0.000849
# Accuracy : 97.84
# ---------------------
# epoch : 833 | loss : 0.000846
# Accuracy : 97.88
# ---------------------
# epoch : 834 | loss : 0.000845
# Accuracy : 97.90
# ---------------------
# epoch : 835 | loss : 0.000843
# Accuracy : 97.87
# ---------------------
# epoch : 836 | loss : 0.000841
# Accuracy : 97.89
# ---------------------
# epoch : 837 | loss : 0.000839
# Accuracy : 97.87
# ---------------------
# epoch : 838 | loss : 0.000838
# Accuracy : 97.88
# ---------------------
# epoch : 839 | loss : 0.000836
# Accuracy : 97.86
# ---------------------
# epoch : 840 | loss : 0.000833
# Accuracy : 97.89
# ---------------------
# epoch : 841 | loss : 0.000832
# Accuracy : 97.88
# ---------------------
# epoch : 842 | loss : 0.000830
# Accuracy : 97.87
# ---------------------
# epoch : 843 | loss : 0.000829
# Accuracy : 97.86
# ---------------------
# epoch : 844 | loss : 0.000826
# Accuracy : 97.89
# ---------------------
# epoch : 845 | loss : 0.000825
# Accuracy : 97.88
# ---------------------
# epoch : 846 | loss : 0.000823
# Accuracy : 97.92
# ---------------------
# epoch : 847 | loss : 0.000820
# Accuracy : 97.87
# ---------------------
# epoch : 848 | loss : 0.000818
# Accuracy : 97.86
# ---------------------
# epoch : 849 | loss : 0.000818
# Accuracy : 97.91
# ---------------------
# epoch : 850 | loss : 0.000817
# Accuracy : 97.91
# ---------------------
# epoch : 851 | loss : 0.000816
# Accuracy : 97.88
# ---------------------
# epoch : 852 | loss : 0.000812
# Accuracy : 97.87
# ---------------------
# epoch : 853 | loss : 0.000810
# Accuracy : 97.89
# ---------------------
# epoch : 854 | loss : 0.000808
# Accuracy : 97.88
# ---------------------
# epoch : 855 | loss : 0.000808
# Accuracy : 97.88
# ---------------------
# epoch : 856 | loss : 0.000807
# Accuracy : 97.86
# ---------------------
# epoch : 857 | loss : 0.000803
# Accuracy : 97.87
# ---------------------
# epoch : 858 | loss : 0.000802
# Accuracy : 97.89
# ---------------------
# epoch : 859 | loss : 0.000800
# Accuracy : 97.88
# ---------------------
# epoch : 860 | loss : 0.000800
# Accuracy : 97.90
# ---------------------
# epoch : 861 | loss : 0.000798
# Accuracy : 97.86
# ---------------------
# epoch : 862 | loss : 0.000795
# Accuracy : 97.88
# ---------------------
# epoch : 863 | loss : 0.000795
# Accuracy : 97.86
# ---------------------
# epoch : 864 | loss : 0.000794
# Accuracy : 97.89
# ---------------------
# epoch : 865 | loss : 0.000792
# Accuracy : 97.88
# ---------------------
# epoch : 866 | loss : 0.000789
# Accuracy : 97.90
# ---------------------
# epoch : 867 | loss : 0.000787
# Accuracy : 97.91
# ---------------------
# epoch : 868 | loss : 0.000786
# Accuracy : 97.88
# ---------------------
# epoch : 869 | loss : 0.000779
# Accuracy : 97.84
# ---------------------
# epoch : 870 | loss : 0.000784
# Accuracy : 97.91
# ---------------------
# epoch : 871 | loss : 0.000780
# Accuracy : 97.86
# ---------------------
# epoch : 872 | loss : 0.000779
# Accuracy : 97.85
# ---------------------
# epoch : 873 | loss : 0.000778
# Accuracy : 97.88
# ---------------------
# epoch : 874 | loss : 0.000776
# Accuracy : 97.88
# ---------------------
# epoch : 875 | loss : 0.000775
# Accuracy : 97.91
# ---------------------
# epoch : 876 | loss : 0.000773
# Accuracy : 97.87
# ---------------------
# epoch : 877 | loss : 0.000771
# Accuracy : 97.89
# ---------------------
# epoch : 878 | loss : 0.000769
# Accuracy : 97.87
# ---------------------
# epoch : 879 | loss : 0.000767
# Accuracy : 97.86
# ---------------------
# epoch : 880 | loss : 0.000766
# Accuracy : 97.90
# ---------------------
# epoch : 881 | loss : 0.000766
# Accuracy : 97.89
# ---------------------
# epoch : 882 | loss : 0.000764
# Accuracy : 97.89
# ---------------------
# epoch : 883 | loss : 0.000762
# Accuracy : 97.90
# ---------------------
# epoch : 884 | loss : 0.000761
# Accuracy : 97.88
# ---------------------
# epoch : 885 | loss : 0.000758
# Accuracy : 97.88
# ---------------------
# epoch : 886 | loss : 0.000758
# Accuracy : 97.86
# ---------------------
# epoch : 887 | loss : 0.000756
# Accuracy : 97.86
# ---------------------
# epoch : 888 | loss : 0.000755
# Accuracy : 97.91
# ---------------------
# epoch : 889 | loss : 0.000754
# Accuracy : 97.90
# ---------------------
# epoch : 890 | loss : 0.000752
# Accuracy : 97.88
# ---------------------
# epoch : 891 | loss : 0.000749
# Accuracy : 97.89
# ---------------------
# epoch : 892 | loss : 0.000747
# Accuracy : 97.88
# ---------------------
# epoch : 893 | loss : 0.000748
# Accuracy : 97.91
# ---------------------
# epoch : 894 | loss : 0.000746
# Accuracy : 97.90
# ---------------------
# epoch : 895 | loss : 0.000744
# Accuracy : 97.87
# ---------------------
# epoch : 896 | loss : 0.000743
# Accuracy : 97.90
# ---------------------
# epoch : 897 | loss : 0.000741
# Accuracy : 97.90
# ---------------------
# epoch : 898 | loss : 0.000740
# Accuracy : 97.88
# ---------------------
# epoch : 899 | loss : 0.000738
# Accuracy : 97.90
# ---------------------
# epoch : 900 | loss : 0.000735
# Accuracy : 97.89
# ---------------------
# epoch : 901 | loss : 0.000735
# Accuracy : 97.86
# ---------------------
# epoch : 902 | loss : 0.000733
# Accuracy : 97.89
# ---------------------
# epoch : 903 | loss : 0.000734
# Accuracy : 97.94
# ---------------------
# epoch : 904 | loss : 0.000729
# Accuracy : 97.87
# ---------------------
# epoch : 905 | loss : 0.000728
# Accuracy : 97.89
# ---------------------
# epoch : 906 | loss : 0.000728
# Accuracy : 97.90
# ---------------------
# epoch : 907 | loss : 0.000726
# Accuracy : 97.89
# ---------------------
# epoch : 908 | loss : 0.000726
# Accuracy : 97.89
# ---------------------
# epoch : 909 | loss : 0.000723
# Accuracy : 97.88
# ---------------------
# epoch : 910 | loss : 0.000722
# Accuracy : 97.87
# ---------------------
# epoch : 911 | loss : 0.000722
# Accuracy : 97.89
# ---------------------
# epoch : 912 | loss : 0.000720
# Accuracy : 97.89
# ---------------------
# epoch : 913 | loss : 0.000718
# Accuracy : 97.87
# ---------------------
# epoch : 914 | loss : 0.000718
# Accuracy : 97.87
# ---------------------
# epoch : 915 | loss : 0.000717
# Accuracy : 97.91
# ---------------------
# epoch : 916 | loss : 0.000713
# Accuracy : 97.87
# ---------------------
# epoch : 917 | loss : 0.000714
# Accuracy : 97.88
# ---------------------
# epoch : 918 | loss : 0.000711
# Accuracy : 97.87
# ---------------------
# epoch : 919 | loss : 0.000711
# Accuracy : 97.90
# ---------------------
# epoch : 920 | loss : 0.000709
# Accuracy : 97.89
# ---------------------
# epoch : 921 | loss : 0.000708
# Accuracy : 97.87
# ---------------------
# epoch : 922 | loss : 0.000706
# Accuracy : 97.88
# ---------------------
# epoch : 923 | loss : 0.000705
# Accuracy : 97.90
# ---------------------
# epoch : 924 | loss : 0.000702
# Accuracy : 97.87
# ---------------------
# epoch : 925 | loss : 0.000704
# Accuracy : 97.86
# ---------------------
# epoch : 926 | loss : 0.000701
# Accuracy : 97.87
# ---------------------
# epoch : 927 | loss : 0.000698
# Accuracy : 97.86
# ---------------------
# epoch : 928 | loss : 0.000699
# Accuracy : 97.90
# ---------------------
# epoch : 929 | loss : 0.000697
# Accuracy : 97.87
# ---------------------
# epoch : 930 | loss : 0.000696
# Accuracy : 97.92
# ---------------------
# epoch : 931 | loss : 0.000694
# Accuracy : 97.91
# ---------------------
# epoch : 932 | loss : 0.000692
# Accuracy : 97.90
# ---------------------
# epoch : 933 | loss : 0.000692
# Accuracy : 97.87
# ---------------------
# epoch : 934 | loss : 0.000690
# Accuracy : 97.90
# ---------------------
# epoch : 935 | loss : 0.000689
# Accuracy : 97.89
# ---------------------
# epoch : 936 | loss : 0.000686
# Accuracy : 97.87
# ---------------------
# epoch : 937 | loss : 0.000686
# Accuracy : 97.87
# ---------------------
# epoch : 938 | loss : 0.000685
# Accuracy : 97.88
# ---------------------
# epoch : 939 | loss : 0.000684
# Accuracy : 97.87
# ---------------------
# epoch : 940 | loss : 0.000682
# Accuracy : 97.88
# ---------------------
# epoch : 941 | loss : 0.000682
# Accuracy : 97.89
# ---------------------
# epoch : 942 | loss : 0.000679
# Accuracy : 97.86
# ---------------------
# epoch : 943 | loss : 0.000679
# Accuracy : 97.88
# ---------------------
# epoch : 944 | loss : 0.000677
# Accuracy : 97.90
# ---------------------
# epoch : 945 | loss : 0.000676
# Accuracy : 97.88
# ---------------------
# epoch : 946 | loss : 0.000675
# Accuracy : 97.90
# ---------------------
# epoch : 947 | loss : 0.000674
# Accuracy : 97.90
# ---------------------
# epoch : 948 | loss : 0.000674
# Accuracy : 97.90
# ---------------------
# epoch : 949 | loss : 0.000671
# Accuracy : 97.87
# ---------------------
# epoch : 950 | loss : 0.000669
# Accuracy : 97.88
# ---------------------
# epoch : 951 | loss : 0.000668
# Accuracy : 97.88
# ---------------------
# epoch : 952 | loss : 0.000668
# Accuracy : 97.89
# ---------------------
# epoch : 953 | loss : 0.000665
# Accuracy : 97.86
# ---------------------
# epoch : 954 | loss : 0.000665
# Accuracy : 97.90
# ---------------------
# epoch : 955 | loss : 0.000664
# Accuracy : 97.87
# ---------------------
# epoch : 956 | loss : 0.000663
# Accuracy : 97.91
# ---------------------
# epoch : 957 | loss : 0.000661
# Accuracy : 97.88
# ---------------------
# epoch : 958 | loss : 0.000661
# Accuracy : 97.87
# ---------------------
# epoch : 959 | loss : 0.000659
# Accuracy : 97.91
# ---------------------
# epoch : 960 | loss : 0.000658
# Accuracy : 97.90
# ---------------------
# epoch : 961 | loss : 0.000657
# Accuracy : 97.91
# ---------------------
# epoch : 962 | loss : 0.000655
# Accuracy : 97.87
# ---------------------
# epoch : 963 | loss : 0.000653
# Accuracy : 97.89
# ---------------------
# epoch : 964 | loss : 0.000653
# Accuracy : 97.88
# ---------------------
# epoch : 965 | loss : 0.000651
# Accuracy : 97.88
# ---------------------
# epoch : 966 | loss : 0.000651
# Accuracy : 97.89
# ---------------------
# epoch : 967 | loss : 0.000650
# Accuracy : 97.88
# ---------------------
# epoch : 968 | loss : 0.000648
# Accuracy : 97.89
# ---------------------
# epoch : 969 | loss : 0.000647
# Accuracy : 97.88
# ---------------------
# epoch : 970 | loss : 0.000646
# Accuracy : 97.87
# ---------------------
# epoch : 971 | loss : 0.000646
# Accuracy : 97.87
# ---------------------
# epoch : 972 | loss : 0.000643
# Accuracy : 97.89
# ---------------------
# epoch : 973 | loss : 0.000643
# Accuracy : 97.89
# ---------------------
# epoch : 974 | loss : 0.000641
# Accuracy : 97.85
# ---------------------
# epoch : 975 | loss : 0.000640
# Accuracy : 97.87
# ---------------------
# epoch : 976 | loss : 0.000638
# Accuracy : 97.89
# ---------------------
# epoch : 977 | loss : 0.000639
# Accuracy : 97.87
# ---------------------
# epoch : 978 | loss : 0.000638
# Accuracy : 97.88
# ---------------------
# epoch : 979 | loss : 0.000636
# Accuracy : 97.89
# ---------------------
# epoch : 980 | loss : 0.000635
# Accuracy : 97.88
# ---------------------
# epoch : 981 | loss : 0.000634
# Accuracy : 97.88
# ---------------------
# epoch : 982 | loss : 0.000633
# Accuracy : 97.88
# ---------------------
# epoch : 983 | loss : 0.000631
# Accuracy : 97.89
# ---------------------
# epoch : 984 | loss : 0.000630
# Accuracy : 97.88
# ---------------------
# epoch : 985 | loss : 0.000629
# Accuracy : 97.88
# ---------------------
# epoch : 986 | loss : 0.000628
# Accuracy : 97.88
# ---------------------
# epoch : 987 | loss : 0.000628
# Accuracy : 97.87
# ---------------------
# epoch : 988 | loss : 0.000625
# Accuracy : 97.92
# ---------------------
# epoch : 989 | loss : 0.000625
# Accuracy : 97.93
# ---------------------
# epoch : 990 | loss : 0.000623
# Accuracy : 97.90
# ---------------------
# epoch : 991 | loss : 0.000622
# Accuracy : 97.90
# ---------------------
# epoch : 992 | loss : 0.000622
# Accuracy : 97.87
# ---------------------
# epoch : 993 | loss : 0.000621
# Accuracy : 97.87
# ---------------------
# epoch : 994 | loss : 0.000620
# Accuracy : 97.87
# ---------------------
# epoch : 995 | loss : 0.000618
# Accuracy : 97.86
# ---------------------
# epoch : 996 | loss : 0.000617
# Accuracy : 97.89
# ---------------------
# epoch : 997 | loss : 0.000616
# Accuracy : 97.91
# ---------------------
# epoch : 998 | loss : 0.000615
# Accuracy : 97.88
# ---------------------
# epoch : 999 | loss : 0.000614
# Accuracy : 97.89
# ---------------------
# epoch : 1000 | loss : 0.000613
# Accuracy : 97.89
# ---------------------

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.plot(np.arange(0,EPOCHS),loss_list)
plt.subplot(1,2,2)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.plot(np.arange(0,EPOCHS), accuracy_list)
plt.show()

# %%
figure = plt.figure(figsize=(8, 8))
cols, rows = 3, 3
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(dataset_2), size=(1,)).item()
    img, label = dataset_2[sample_idx]
    image = img.reshape(1,784)
    figure.add_subplot(rows, cols, i)
    out = model(image)
    _,predict = torch.max(out.data, 1)
    plt.title("label: {} actual: {}".format(label,predict.item()))
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()
