# %%
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torchvision import datasets
from torch.utils.data import DataLoader
import torch.optim as optim
import torchvision
import numpy as np
from torchvision import transforms

# %%
class n_net(nn.Module):
    def __init__(self):
        super(n_net,self).__init__()
        self.n1 = nn.Linear(784,100)
        self.relu = nn.ReLU()
        self.n2 = nn.Linear(100,100)
        self.n3 = nn.Linear(100,10)
    def forward(self,x):
        x1 = self.n1(x)
        x2 = self.relu(x1)
        x3 = self.n2(x2)
        x4 = self.relu(x3)
        x5 = self.n3(x4)
        return x5

# %%
USE_CUDA = torch.cuda.is_available()
device = torch.device("cuda" if USE_CUDA else "cpu")

# %%
DOWNLOAD_ROOT = 'MNIST_data/'

dataset_1 = datasets.MNIST(root=DOWNLOAD_ROOT,train=True,transform=transforms.ToTensor(),download=True)
dataset_2 = datasets.MNIST(root=DOWNLOAD_ROOT,train=False,transform=transforms.ToTensor(),download=True)

# %%
BATCH_SIZE = 128
dataset_1_loader = DataLoader(dataset_1, batch_size=BATCH_SIZE, shuffle=True,drop_last=True)
dataset_2_loader = DataLoader(dataset_2, batch_size=BATCH_SIZE, shuffle=True,drop_last=True)

# %%
LEARNING_RATE = 0.01
torch.manual_seed(7777)
if device == 'cuda':
    torch.cuda.manual_seed_all(777)

model = n_net()
model.zero_grad()
loss_function = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(),lr=LEARNING_RATE)

# %%
TOTAL_BATCH = len(dataset_1_loader)
EPOCHS = np.arange(0,100)
loss_list = []
accuracy_list = []
for epoch in EPOCHS:
    cost = 0
    for image, label in dataset_1_loader:
        image = image.reshape(BATCH_SIZE,784)
        optimizer.zero_grad()
        predicted = model.forward(image)
        loss = loss_function(predicted,label)
        loss.backward()
        optimizer.step()
        cost+=loss
    with torch.no_grad():
        total = 0
        correct = 0
        for image, label in dataset_2_loader:
            image = image.reshape(BATCH_SIZE,784)
            out = model(image)
            _,predict = torch.max(out.data, 1)
            total += label.size(0)
            correct += (predict==label).sum()
    average_cost = cost/TOTAL_BATCH
    accuracy = 100*correct/total
    loss_list.append(average_cost.detach().numpy())
    accuracy_list.append(accuracy)
    print("epoch : {} | loss : {:.6f}" .format(epoch, average_cost))
    print("Accuracy : {:.2f}".format(accuracy))
    print("---------------------")
# Out:
# epoch : 0 | loss : 2.178835
# Accuracy : 57.07
# ---------------------
# epoch : 1 | loss : 1.333699
# Accuracy : 80.81
# ---------------------
# epoch : 2 | loss : 0.680126
# Accuracy : 85.70
# ---------------------
# epoch : 3 | loss : 0.496338
# Accuracy : 88.24
# ---------------------
# epoch : 4 | loss : 0.420924
# Accuracy : 89.54
# ---------------------
# epoch : 5 | loss : 0.380197
# Accuracy : 90.07
# ---------------------
# epoch : 6 | loss : 0.353888
# Accuracy : 90.79
# ---------------------
# epoch : 7 | loss : 0.334613
# Accuracy : 91.02
# ---------------------
# epoch : 8 | loss : 0.319357
# Accuracy : 91.41
# ---------------------
# epoch : 9 | loss : 0.306695
# Accuracy : 91.79
# ---------------------
# epoch : 10 | loss : 0.295452
# Accuracy : 91.92
# ---------------------
# epoch : 11 | loss : 0.285000
# Accuracy : 92.24
# ---------------------
# epoch : 12 | loss : 0.275961
# Accuracy : 92.57
# ---------------------
# epoch : 13 | loss : 0.267229
# Accuracy : 92.91
# ---------------------
# epoch : 14 | loss : 0.258871
# Accuracy : 92.90
# ---------------------
# epoch : 15 | loss : 0.250985
# Accuracy : 93.24
# ---------------------
# epoch : 16 | loss : 0.243173
# Accuracy : 93.48
# ---------------------
# epoch : 17 | loss : 0.235975
# Accuracy : 93.65
# ---------------------
# epoch : 18 | loss : 0.228981
# Accuracy : 93.80
# ---------------------
# epoch : 19 | loss : 0.222705
# Accuracy : 93.90
# ---------------------
# epoch : 20 | loss : 0.216587
# Accuracy : 93.93
# ---------------------
# epoch : 21 | loss : 0.210622
# Accuracy : 94.00
# ---------------------
# epoch : 22 | loss : 0.205088
# Accuracy : 94.35
# ---------------------
# epoch : 23 | loss : 0.199606
# Accuracy : 94.31
# ---------------------
# epoch : 24 | loss : 0.194962
# Accuracy : 94.46
# ---------------------
# epoch : 25 | loss : 0.190284
# Accuracy : 94.60
# ---------------------
# epoch : 26 | loss : 0.185670
# Accuracy : 94.75
# ---------------------
# epoch : 27 | loss : 0.181110
# Accuracy : 94.87
# ---------------------
# epoch : 28 | loss : 0.176914
# Accuracy : 95.07
# ---------------------
# epoch : 29 | loss : 0.172917
# Accuracy : 94.96
# ---------------------
# epoch : 30 | loss : 0.169263
# Accuracy : 95.11
# ---------------------
# epoch : 31 | loss : 0.165302
# Accuracy : 95.26
# ---------------------
# epoch : 32 | loss : 0.162011
# Accuracy : 95.25
# ---------------------
# epoch : 33 | loss : 0.158607
# Accuracy : 95.37
# ---------------------
# epoch : 34 | loss : 0.154983
# Accuracy : 95.47
# ---------------------
# epoch : 35 | loss : 0.151858
# Accuracy : 95.51
# ---------------------
# epoch : 36 | loss : 0.149222
# Accuracy : 95.66
# ---------------------
# epoch : 37 | loss : 0.146102
# Accuracy : 95.60
# ---------------------
# epoch : 38 | loss : 0.143307
# Accuracy : 95.73
# ---------------------
# epoch : 39 | loss : 0.140693
# Accuracy : 95.86
# ---------------------
# epoch : 40 | loss : 0.137880
# Accuracy : 95.81
# ---------------------
# epoch : 41 | loss : 0.135456
# Accuracy : 95.94
# ---------------------
# epoch : 42 | loss : 0.133020
# Accuracy : 96.07
# ---------------------
# epoch : 43 | loss : 0.130753
# Accuracy : 96.17
# ---------------------
# epoch : 44 | loss : 0.128321
# Accuracy : 96.17
# ---------------------
# epoch : 45 | loss : 0.125987
# Accuracy : 96.30
# ---------------------
# epoch : 46 | loss : 0.123804
# Accuracy : 96.19
# ---------------------
# epoch : 47 | loss : 0.121799
# Accuracy : 96.41
# ---------------------
# epoch : 48 | loss : 0.119709
# Accuracy : 96.41
# ---------------------
# epoch : 49 | loss : 0.117780
# Accuracy : 96.45
# ---------------------
# epoch : 50 | loss : 0.115725
# Accuracy : 96.34
# ---------------------
# epoch : 51 | loss : 0.114093
# Accuracy : 96.47
# ---------------------
# epoch : 52 | loss : 0.112142
# Accuracy : 96.52
# ---------------------
# epoch : 53 | loss : 0.110337
# Accuracy : 96.57
# ---------------------
# epoch : 54 | loss : 0.108667
# Accuracy : 96.67
# ---------------------
# epoch : 55 | loss : 0.106867
# Accuracy : 96.60
# ---------------------
# epoch : 56 | loss : 0.105311
# Accuracy : 96.67
# ---------------------
# epoch : 57 | loss : 0.103625
# Accuracy : 96.74
# ---------------------
# epoch : 58 | loss : 0.102175
# Accuracy : 96.64
# ---------------------
# epoch : 59 | loss : 0.100591
# Accuracy : 96.84
# ---------------------
# epoch : 60 | loss : 0.099085
# Accuracy : 96.90
# ---------------------
# epoch : 61 | loss : 0.097611
# Accuracy : 96.77
# ---------------------
# epoch : 62 | loss : 0.096163
# Accuracy : 96.85
# ---------------------
# epoch : 63 | loss : 0.094749
# Accuracy : 96.93
# ---------------------
# epoch : 64 | loss : 0.093321
# Accuracy : 96.98
# ---------------------
# epoch : 65 | loss : 0.092003
# Accuracy : 96.93
# ---------------------
# epoch : 66 | loss : 0.090747
# Accuracy : 97.02
# ---------------------
# epoch : 67 | loss : 0.089499
# Accuracy : 97.06
# ---------------------
# epoch : 68 | loss : 0.088094
# Accuracy : 97.00
# ---------------------
# epoch : 69 | loss : 0.087169
# Accuracy : 97.08
# ---------------------
# epoch : 70 | loss : 0.085749
# Accuracy : 97.16
# ---------------------
# epoch : 71 | loss : 0.084665
# Accuracy : 97.18
# ---------------------
# epoch : 72 | loss : 0.083446
# Accuracy : 97.08
# ---------------------
# epoch : 73 | loss : 0.082479
# Accuracy : 97.22
# ---------------------
# epoch : 74 | loss : 0.081191
# Accuracy : 97.21
# ---------------------
# epoch : 75 | loss : 0.080110
# Accuracy : 97.18
# ---------------------
# epoch : 76 | loss : 0.079034
# Accuracy : 97.30
# ---------------------
# epoch : 77 | loss : 0.078128
# Accuracy : 97.29
# ---------------------
# epoch : 78 | loss : 0.077101
# Accuracy : 97.24
# ---------------------
# epoch : 79 | loss : 0.076002
# Accuracy : 97.13
# ---------------------
# epoch : 80 | loss : 0.075196
# Accuracy : 97.20
# ---------------------
# epoch : 81 | loss : 0.074138
# Accuracy : 97.30
# ---------------------
# epoch : 82 | loss : 0.073101
# Accuracy : 97.29
# ---------------------
# epoch : 83 | loss : 0.072252
# Accuracy : 97.32
# ---------------------
# epoch : 84 | loss : 0.071456
# Accuracy : 97.28
# ---------------------
# epoch : 85 | loss : 0.070509
# Accuracy : 97.35
# ---------------------
# epoch : 86 | loss : 0.069645
# Accuracy : 97.31
# ---------------------
# epoch : 87 | loss : 0.068750
# Accuracy : 97.39
# ---------------------
# epoch : 88 | loss : 0.068040
# Accuracy : 97.32
# ---------------------
# epoch : 89 | loss : 0.067063
# Accuracy : 97.40
# ---------------------
# epoch : 90 | loss : 0.066229
# Accuracy : 97.38
# ---------------------
# epoch : 91 | loss : 0.065473
# Accuracy : 97.45
# ---------------------
# epoch : 92 | loss : 0.064639
# Accuracy : 97.43
# ---------------------
# epoch : 93 | loss : 0.063638
# Accuracy : 97.42
# ---------------------
# epoch : 94 | loss : 0.063117
# Accuracy : 97.43
# ---------------------
# epoch : 95 | loss : 0.062301
# Accuracy : 97.42
# ---------------------
# epoch : 96 | loss : 0.061613
# Accuracy : 97.51
# ---------------------
# epoch : 97 | loss : 0.060925
# Accuracy : 97.43
# ---------------------
# epoch : 98 | loss : 0.060031
# Accuracy : 97.54
# ---------------------
# epoch : 99 | loss : 0.059348
# Accuracy : 97.62
# ---------------------

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.plot(EPOCHS,loss_list)
plt.subplot(1,2,2)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.plot(EPOCHS, accuracy_list)
plt.show()
